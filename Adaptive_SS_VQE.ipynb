# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.34.0-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.11.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.2.1)
# Collecting rustworkx (from pennylane)
#   Downloading rustworkx-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 38.2 MB/s eta 0:00:00
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.6.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.4.4)
# Collecting semantic-version>=2.7 (from pennylane)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autoray>=0.6.1 (from pennylane)
#   Downloading autoray-0.6.8-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.3.2)
# Collecting pennylane-lightning>=0.34 (from pennylane)
#   Downloading PennyLane_Lightning-0.34.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 49.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.9.0)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2024.2.2)
# Installing collected packages: semantic-version, rustworkx, autoray, pennylane-lightning, pennylane
# Successfully installed autoray-0.6.8 pennylane-0.34.0 pennylane-lightning-0.34.0 rustworkx-0.14.0 semantic-version-2.10.0

# %%
import pennylane as qml
import pennylane.numpy as np
import matplotlib.pyplot as plt

# %%
def hydrogen_hamiltonian(coordinates):
    """Calculates the qubit Hamiltonian of the hydrogen molecule.

    Args:
        coordinates (list(float)): Cartesian coordinates of each hydrogen molecule.
        charge (int): The electric charge given to the hydrogen molecule.

    Returns:
        (qml.Hamiltonian): A PennyLane Hamiltonian.
    """
    return qml.qchem.molecular_hamiltonian(["H", "Li"], coordinates, charge=0, basis="STO-3G",active_electrons=2)[0]


def hf(electrons, num_qubits):
    """Calculates the Hartree-Fock state of the hydrogen molecule.

    Args:
        electrons (int): The number of electrons in the hydrogen molecule.
        num_qubits (int): The number of qubits needed to represent the hydrogen molecule Hamiltonian.

    Returns:
        (numpy.tensor): The HF state.
    """
    # Put your solution here #
    return qml.qchem.hf_state(electrons=electrons, orbitals=num_qubits)

# %% [markdown]
# Using exact diagonalization to get the ground state and first excited state.

# %%
L=1.5
coordinates = np.array([0.0, 0.0, -L/2, 0.0, 0.0, L/2]) #np.array([-L/2/np.sqrt(3), L/2, 0.0, L/np.sqrt(3), 0.0, 0.0,-L/2/np.sqrt(3), -L/2, 0.0])
charge=0
hamiltonian = hydrogen_hamiltonian(np.array(coordinates))
H_matrix=qml.matrix(hamiltonian)

# %%
vals, vecs = np.linalg.eigh(H_matrix)

inds=np.argsort(vals)
eng=vals[inds]
vec=vecs[:,inds]

print('The ground state energy:',eng[0])
# Out:
# The ground state energy: -7.626624465547493

# %%
def vec_check(vec,electron_num):
    for i,e in enumerate(vec):
        if np.abs(e) > 1e-8:
            e_occ=bin(i)[2:]
            lst=' '.join(e_occ).split(' ')
            cv=tuple(map(int, lst))
            e_num=sum(cv)
            if e_num!=electron_num:
                return False
    return True

# %%
sz=qml.qchem.spinz(len(hamiltonian.wires))
SZ=qml.matrix(sz)
Stop=[False,False,False]
elec_num=2
for i in range(1,len(eng)): # Finding first excited state with -1 Sz
    Sz=vec[:,i].dot(SZ.dot(np.transpose(np.conjugate(vec[:,i]))))

    if np.abs(Sz) < 1e-5 and vec_check(vec[:,i],elec_num):
        print('The first excied state energy with sz=0:',eng[i])
        Stop[0]=True

    elif np.abs(Sz-1) < 1e-5 and vec_check(vec[:,i],elec_num):
        print('The first excied state energy with sz=1:',eng[i])
        Stop[1]=True

    elif np.abs(Sz+1) < 1e-5 and vec_check(vec[:,i],elec_num):
        print('The first excied state energy with sz=-1:',eng[i])
        Stop[2]=True

    if np.all(Stop):
        break
# Out:
# The first excied state energy with sz=1: -7.522914627103037
# The first excied state energy with sz=0: -7.522914627103034
# The first excied state energy with sz=-1: -7.52291462710303

# %%
def bit_to_vec(bitstring_dict,num_qubits):
    vec=np.zeros(2**num_qubits)
    amp=0
    for i in range(2**num_qubits):
        bitstr=bin(i)[2:]
        if len(bitstr) < num_qubits:
            bitstr=(num_qubits-len(bitstr))*'0'+bitstr

        if bitstr in bitstring_dict:
            vec[i]=bitstring_dict[bitstr]
            amp+=np.abs(bitstring_dict[bitstr])**2
    vec=vec/np.sqrt(amp)
    return vec

# %%
class SS_vqe_ch():
    def __init__(self,state_lst,num_electrons,symbol,geometry,charge) -> None:
        self.num_electrons=num_electrons
        self.symbol=symbol
        self.geometry=geometry
        self.charge=charge

        self.hamiltonian=self.Ch_hamiltonian(symbol,geometry,num_electrons,charge)
        self.num_qubits = len(self.hamiltonian.wires)
        self.sz=qml.qchem.spinz(self.num_qubits)
        self.singles, self.doubles = qml.qchem.excitations(self.num_electrons, self.num_qubits)
        self.state_lst=[]
        for stat in state_lst:
            self.state_lst.append(bit_to_vec(stat,self.num_qubits))
        H_matrix=qml.matrix(self.hamiltonian)
        H_sq=H_matrix.dot(H_matrix)

        self.H_sq_ob=qml.Hermitian(H_sq, wires=range(self.num_qubits))
        self.dev = qml.device("default.qubit", wires=self.num_qubits)
        self.cost_h_fn = qml.QNode(self.circuit, self.dev)
        self.Sz_fn = qml.QNode(self.circuit_sz, self.dev)

    def Ch_hamiltonian(self,symbol,geometry,num_electrons,charge):
        return qml.qchem.molecular_hamiltonian(symbol, geometry, charge=charge,\
                                               basis="STO-3G",active_electrons=num_electrons)[0]

    def hf(self,electrons, num_qubits):
        return qml.qchem.hf_state(electrons=electrons, orbitals=num_qubits)

    def circuit(self,state,weights):
        qml.StatePrep(state, wires=range(self.num_qubits))
        d_l=len(self.doubles)
        s_l=len(self.singles)
        for j in range(self.num_layer):
            for i in range(len(self.singles)):
                qml.SingleExcitation(weights[i+d_l+j*(d_l+s_l)], wires=self.singles[i])
            for i in range(len(self.doubles)):
                qml.DoubleExcitation(weights[i+j*(d_l+s_l)], wires=self.doubles[i])
        return qml.expval(self.hamiltonian)


    def circuit_sz(self,state,weights):
        qml.StatePrep(state, wires=range(self.num_qubits))
        d_l=len(self.doubles)
        s_l=len(self.singles)
        for j in range(self.num_layer):
            for i in range(len(self.singles)):
                qml.SingleExcitation(weights[i+d_l+j*(d_l+s_l)], wires=self.singles[i])
            for i in range(len(self.doubles)):
                qml.DoubleExcitation(weights[i+j*(d_l+s_l)], wires=self.doubles[i])
        return qml.expval(self.sz)

    def cost_fn(self,params):
        cost=0
        for ind, stat in enumerate(self.state_lst):
            cost+=self.w[ind]*self.cost_h_fn(stat,params)
        return cost

    def run(self,w=None,epochs=400,stepsize=0.5,num_layer=2,cov=1e-6,print_train=True):
        if w==None:
            self.w=[1.0]+(len(self.state_lst)-1)*[0.5]
        else:
            self.w=w

        self.num_layer=num_layer
        opt = qml.AdamOptimizer(stepsize=stepsize)
        self.weights =np.zeros(num_layer*len(self.doubles + self.singles), requires_grad=True)

        i=0
        iter=[]
        cost_val=[]
        Lowest_cost=0
        self.best_weights=self.weights

        cov=cov
        E_pev=[0.0]*len(self.state_lst)
        E_lst=[0.0]*len(self.state_lst)
        E_pev=np.array(E_pev)
        E_lst=np.array(E_lst)
        for _ in range(epochs):
            self.weights = opt.step(self.cost_fn, self.weights)
            iter.append(i)
            cost=self.cost_fn(self.weights)
            for j,stat in enumerate(self.state_lst):
                E_lst[j]=self.cost_h_fn(stat,self.weights)

            if Lowest_cost>cost:
                Lowest_cost=cost
                self.best_weights=self.weights
            cost_val.append(E_lst)

            i=i+1
            if print_train:
                print('iter:',i)
                for j,stat in enumerate(self.state_lst):
                    print(' E0:',E_lst[j],' Sz:',self.Sz_fn(stat,self.weights))
            E_diff=np.abs(E_lst-E_pev)
            if np.all(E_diff<cov):
                break

            #for k in range(len(self.state_lst)):
            E_pev=E_lst.copy()
        self.E_lst=E_lst
        return E_lst

# %%
L=1.5
symbol=["H", "Li"]
geometry=np.array([0.0, 0.0, -L/2, 0.0, 0.0, L/2])

charge=0
num_electrons=2
g_stat={'1100000000': 1}
e_stat_p1={'1010000000': 1}
e_stat_m1={'0101000000': 1}
e_stat_0={'0110000000': 1,'1001000000': 1}
stat_lst=[g_stat,e_stat_p1,e_stat_m1,e_stat_0]
ss_vqe=SS_vqe_ch(stat_lst,num_electrons,symbol,geometry,charge)

# %%
E0,E1p1,E1m1,E1_0=ss_vqe.run()
# Out:
# iter: 1
#  E0: -7.114361086861115  Sz: 0.0
#  E0: -7.464140817197321  Sz: 1.0
#  E0: -7.464032961677203  Sz: -1.0
#  E0: -7.4639406502334085  Sz: -8.326672684688674e-17
# iter: 2
#  E0: -7.206854536072497  Sz: 0.0
#  E0: -7.49408793966439  Sz: 1.0
#  E0: -7.498316375839986  Sz: -1.0
#  E0: -7.495944851828021  Sz: 5.551115123125783e-17
# iter: 3
#  E0: -7.403765724131152  Sz: -5.551115123125783e-17
#  E0: -7.510131345584048  Sz: 1.0
#  E0: -7.513275162000521  Sz: -1.0
#  E0: -7.500083460776256  Sz: 0.0
# iter: 4
#  E0: -7.388160843037501  Sz: 5.551115123125783e-17
#  E0: -7.515238978025504  Sz: 0.9999999999999997
#  E0: -7.522764929500574  Sz: 2.7755575615628914e-17

# %%
electrons = 2
num_qubits = len(hamiltonian.wires)

S2 = qml.qchem.spin2(electrons, num_qubits)
sz=qml.qchem.spinz(num_qubits)

singles, doubles = qml.qchem.excitations(electrons, num_qubits)
pool_operators=singles+doubles

num_qubits = len(hamiltonian.wires)
hf_state = hf(electrons, num_qubits)

dev = qml.device("default.qubit", wires=num_qubits)
print("The original vqe use ",len(doubles)*13 + len(singles)*2," cnot gates")
print("The original vqe use ",len(doubles)*34 + len(singles)*10," gates")

bitstr=''.join(map(str, hf_state))

g_trial_stat={bitstr: 1}
e_trial_stat_szp1={'1010000000': 1}
e_trial_stat_szm1={'0101000000': 1}
e_trial_stat_sz0={'1001000000': 1,'0110000000': 1}

def bit_to_vec(bitstring_dict,num_qubits):
    vec=np.zeros(2**num_qubits)
    amp=0
    for i in range(2**num_qubits):
        bitstr=bin(i)[2:]
        if len(bitstr) < num_qubits:
            bitstr=(num_qubits-len(bitstr))*'0'+bitstr
        #print(bitstr)
        if bitstr in bitstring_dict:
            vec[i]=bitstring_dict[bitstr]
            amp+=np.abs(bitstring_dict[bitstr])**2
    vec=vec/np.sqrt(amp)
    return vec

g_stat=bit_to_vec(g_trial_stat,num_qubits)
e_stat_szp1=bit_to_vec(e_trial_stat_szp1,num_qubits)
e_stat_szm1=bit_to_vec(e_trial_stat_szm1,num_qubits)
e_stat_sz0=bit_to_vec(e_trial_stat_sz0,num_qubits)

def circuit(state,weights):
    qml.StatePrep(state, wires=range(num_qubits))
    for i in range(len(singles)):
        qml.SingleExcitation(weights[i+len(doubles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(weights[i], wires=doubles[i])

    for i in range(len(singles)):
        qml.SingleExcitation(weights[i+2*len(doubles)+len(singles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(weights[i+len(doubles)+len(singles)], wires=doubles[i])

    return qml.expval(hamiltonian)

def circuit_sz(state,weights):
    qml.StatePrep(state, wires=range(num_qubits))
    for i in range(len(singles)):
        qml.SingleExcitation(weights[i+len(doubles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(weights[i], wires=doubles[i])

    for i in range(len(singles)):
        qml.SingleExcitation(weights[i+2*len(doubles)+len(singles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(weights[i+len(doubles)+len(singles)], wires=doubles[i])
    return qml.expval(sz)


cost_h_fn = qml.QNode(circuit, dev)
Sz_fn = qml.QNode(circuit_sz, dev)

def cost_fn(params):
    return cost_h_fn(g_stat,params)+0.5*cost_h_fn(e_stat_szp1,params)+0.5*cost_h_fn(e_stat_szm1,params)\
            +0.5*cost_h_fn(e_stat_sz0,params)

weights =np.zeros(2*len(doubles + singles), requires_grad=True)

opt = qml.AdamOptimizer(stepsize=0.5)

i=0
iter=[]
cost_val=[]
Lowest_E=0
best_weights=0

cov=1e-5
E0_pev=0
E1_pev=0
E2_pev=0
E3_pev=0

for _ in range(400):
    weights = opt.step(cost_fn, weights)
    iter.append(i)

    E0=cost_h_fn(g_stat,weights)
    E1=cost_h_fn(e_stat_szp1,weights)
    E2=cost_h_fn(e_stat_sz0,weights)
    E3=cost_h_fn(e_stat_szm1,weights)

    if Lowest_E>E0:
        Lowest_E=E0
        best_weights=weights
    cost_val.append(E0)

    i=i+1
    print('Need iter:',i,' E0:',E0,', E1:',E1,' Sz:',Sz_fn(e_stat_szp1,weights))
    print('E2:',E2,Sz_fn(e_stat_sz0,weights))
    print('E3:',E3,Sz_fn(e_stat_szm1,weights))
    if np.abs(E0-E0_pev)<cov and np.abs(E1-E1_pev)<cov and np.abs(E2-E2_pev)<cov and np.abs(E3-E3_pev)<cov:
        print('Need iter:',i,' E0:',E0,', E1:',E1,' Sz:',Sz_fn(e_stat_szp1,weights))
        print('E2:',E2,Sz_fn(e_stat_sz0,weights))
        print('E3:',E3,Sz_fn(e_stat_szm1,weights))
        break

    E0_pev=E0
    E1_pev=E1
    E2_pev=E2
    E3_pev=E3
# Out:
# The original vqe use  224  cnot gates
# The original vqe use  624  gates
# Need iter: 1  E0: -7.114361086861115 , E1: -7.464140817197321  Sz: 1.0
# E2: -7.4639406502334085 -8.326672684688674e-17
# E3: -7.464032961677203 -1.0
# Need iter: 2  E0: -7.206854536072497 , E1: -7.49408793966439  Sz: 1.0
# E2: -7.495944851828021 5.551115123125783e-17
# E3: -7.498316375839986 -1.0
# Need iter: 3  E0: -7.403765724131152 , E1: -7.510131345584048  Sz: 1.0
# E2: -7.500083460776256 0.0
# E3: -7.513275162000521 -1.0
# Need iter: 4  E0: -7.388160843037501 , E1: -7.515238978025504  Sz: 0.9999999999999997
# E2: -7.510460289070379 -2.7755575615628914e-17
# E3: -7.516227935536564 -0.9999999999999997
# Need iter: 5  E0: -7.473409277364713 , E1: -7.49417707357977  Sz: 0.9999999999999999
# E2: -7.500834585541014 0.0
# E3: -7.50596459664734 -1.0
# Need iter: 6  E0: -7.463527924576138 , E1: -7.493139935867371  Sz: 1.0
# E2: -7.496506836570258 0.0
# E3: -7.509698517436156 -0.9999999999999998
# Need iter: 7  E0: -7.402949539510246 , E1: -7.50729549662927  Sz: 0.9999999999999997
# E2: -7.505811953239703 5.551115123125783e-17
# E3: -7.515795095778095 -1.0
# Need iter: 8  E0: -7.445959856973898 , E1: -7.5167697132543045  Sz: 1.0
# E2: -7.512838742582188 0.0
# E3: -7.517181314165187 -1.0000000000000002
# Need iter: 9  E0: -7.488462015920548 , E1: -7.5204485793023625  Sz: 1.0
# E2: -7.515325908781966 0.0
# E3: -7.517441324904997 -1.0
# Need iter: 10  E0: -7.506771745478024 , E1: -7.5219782804880975  Sz: 1.0000000000000002
# E2: -7.515311738090895 8.326672684688674e-17
# E3: -7.518335666973624 -1.0
# Need iter: 11  E0: -7.5235835205322354 , E1: -7.522482907835084  Sz: 1.0000000000000002
# E2: -7.513424152326901 2.7755575615628914e-17
# E3: -7.516895849635448 -1.0
# Need iter: 217  E0: -7.626461585783486 , E1: -7.522912113248847  Sz: 1.0
# E2: -7.522656562304767 2.7755575615628914e-17
# E3: -7.522609743569112 -0.9999999999999998
# Need iter: 218  E0: -7.626456778791579 , E1: -7.522912927123169  Sz: 1.0
# E2: -7.522675891620736 2.7755575615628914e-17
# E3: -7.522610387109784 -0.9999999999999998
# Need iter: 219  E0: -7.626452453168302 , E1: -7.522913312271245  Sz: 1.0
# E2: -7.522692434148879 0.0
# E3: -7.5226104708314745 -1.0
# Need iter: 220  E0: -7.626448487785835 , E1: -7.522913369163414  Sz: 0.9999999999999999
# E2: -7.522706703870438 -5.551115123125783e-17
# E3: -7.5226100514641 -1.0
# Need iter: 221  E0: -7.626444757967218 , E1: -7.522913152620722  Sz: 0.9999999999999999
# E2: -7.5227192511093754 2.7755575615628914e-17
# E3: -7.522609184137246 -1.0
# Need iter: 222  E0: -7.626441269168077 , E1: -7.522912729831648  Sz: 1.0000000000000002
# E2: -7.5227300681477205 -5.551115123125783e-17
# E3: -7.522608180402212 -1.0
# Need iter: 223  E0: -7.626438284825401 , E1: -7.522912145739957  Sz: 0.9999999999999998
# E2: -7.5227386690911295 2.7755575615628914e-17
# E3: -7.522607302603256 -1.0
# Need iter: 223  E0: -7.626438284825401 , E1: -7.522912145739957  Sz: 0.9999999999999998
# E2: -7.5227386690911295 2.7755575615628914e-17
# E3: -7.522607302603256 -1.0

# %%
electrons = 2
num_qubits = len(hamiltonian.wires)

singles, doubles = qml.qchem.excitations(electrons, num_qubits)
pool_operators=singles+doubles

num_qubits = len(hamiltonian.wires)
hf_state = hf(electrons, num_qubits)

def circuit_1(state,weights,excitations):
    qml.StatePrep(state, wires=range(num_qubits))
    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(weights[i], wires=excitation)
        else:
            qml.SingleExcitation(weights[i], wires=excitation)
    return qml.expval(hamiltonian)

def circuit_sz(state,weights,excitations):
    qml.StatePrep(state, wires=range(num_qubits))
    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(weights[i], wires=excitation)
        else:
            qml.SingleExcitation(weights[i], wires=excitation)
    return qml.expval(sz)

dev = qml.device("default.qubit", wires=num_qubits)#

cost_h_fn = qml.QNode(circuit_1, dev, expansion_strategy="device")
Sz_fn = qml.QNode(circuit_sz, dev)

def cost_fn(params, excitations):
    return cost_h_fn(g_stat,params, excitations)+0.45*cost_h_fn(e_stat_szp1,params, excitations)\
            +0.45*cost_h_fn(e_stat_szm1,params, excitations)+0.2*cost_h_fn(e_stat_sz0,params, excitations)


epochs=400

energy=[]
operator_circuits=[]# doubles_select+singles_select

weights = [] #[0.0] * len(operator_circuits)
weights=np.array(weights)

opt = opt = qml.GradientDescentOptimizer(stepsize=0.4)

circuit_gradient = qml.grad(cost_fn, argnum=0)


E0 = cost_h_fn(g_stat,weights, operator_circuits)
E1 = cost_h_fn(e_stat_szp1,weights, operator_circuits)
E2 = cost_h_fn(e_stat_sz0,weights, operator_circuits)
E3 = cost_h_fn(e_stat_szm1,weights, operator_circuits)

print(f"Epoch = 0, G Energy = {E0:.8f} Ha, E1 Energy = {E1:.8f} Ha,")
print(f" E2 Energy = {E1:.8f} Ha")
print("Number of gates = {}\n".format(len(operator_circuits)))

configs=qml.specs(cost_h_fn)(g_stat,weights, excitations=operator_circuits)

#print(configs)
print("Circuit depth {}\n".format(configs['resources'].depth))

conv=1e-6
E0_pev=0
E1_pev=0
E2_pev=0
E3_pev=0
for n in range(epochs):

    Test_set=operator_circuits+pool_operators
    Test_params=list(weights)+[0.0]*len(pool_operators)
    Test_params=np.array(Test_params)


    test_grads = circuit_gradient(Test_params,Test_set)
    test_grads = test_grads[len(weights):]
    maxpos = np.argmax(np.abs(test_grads))
    print('Max grad',np.max(np.abs(test_grads)))

    if n<= 40 or np.abs(test_grads[maxpos])<0.05:
        max_op=pool_operators[maxpos]
        operator_circuits.append(max_op)
        weights=np.append(weights, 0.0)

    weights,_ = opt.step(cost_fn, weights, operator_circuits) # Step 11.
    E0 = cost_h_fn(g_stat,weights,operator_circuits)
    E1 = cost_h_fn(e_stat_szp1,weights, operator_circuits)
    E2 = cost_h_fn(e_stat_sz0,weights, operator_circuits)
    E3 = cost_h_fn(e_stat_szm1,weights, operator_circuits)

    print(f"Epoch = {n+1}, G Energy = {E0:.8f} Ha, Sz = {Sz_fn(g_stat,weights,operator_circuits):.8f} Ha,")
    print(f" The first excited state Energy = {E1:.8f} Ha, Sz= {Sz_fn(e_stat_szp1,weights,operator_circuits):.8f}")
    print(f" The first excited state Energy = {E2:.8f} Ha, Sz= {Sz_fn(e_stat_sz0,weights,operator_circuits):.8f}")
    print(f" The first excited state Energy = {E3:.8f} Ha, Sz = {Sz_fn(e_stat_szm1,weights,operator_circuits):.8f}")
    print("Number of gates = {}\n".format(len(operator_circuits)))
    configs=qml.specs(cost_h_fn)(g_stat,weights, excitations=operator_circuits)
    print("Circuit depth {}\n".format(configs['resources'].depth))

    if np.abs(E0-E0_pev)<cov and np.abs(E1-E1_pev)<cov and np.abs(E3-E3_pev)<cov:
        break

    E0_pev=E0
    E1_pev=E1
    E2_pev=E2
    E3_pev=E3
# Out:
# Epoch = 0, G Energy = -7.60898166 Ha, E1 Energy = -7.49074895 Ha,
#  E2 Energy = -7.49074895 Ha
# Number of gates = 0
#
# Circuit depth 1
#
# Max grad 0.12296176040542098
# Epoch = 1, G Energy = -7.61431460 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.49074895 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.49074895 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.49074895 Ha, Sz = -1.00000000
# Number of gates = 1
#
# Circuit depth 2
#
# Max grad 0.09384808786854848
# Epoch = 2, G Energy = -7.61967928 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.49074895 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.49074895 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.49074895 Ha, Sz = -1.00000000
# Number of gates = 2
#
# Circuit depth 3
#
# Max grad 0.0734423026356488
# Epoch = 3, G Energy = -7.62102202 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.49074895 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.49263893 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.49453477 Ha, Sz = -1.00000000
# Number of gates = 3
#
# Circuit depth 4
#
# Max grad 0.07327629036417202
# Epoch = 4, G Energy = -7.62102119 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.49452650 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.49598449 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.49744643 Ha, Sz = -1.00000000
# Number of gates = 4
#
# Circuit depth 4
#
# Max grad 0.06024389440837746
# Epoch = 5, G Energy = -7.62006795 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50016534 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.49993650 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.49970777 Ha, Sz = -1.00000000
# Number of gates = 5
#
# Circuit depth 5
#
# Max grad 0.040918859301675756
# Epoch = 6, G Energy = -7.61849921 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50340709 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50328781 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50316856 Ha, Sz = -1.00000000
# Number of gates = 6
#
# Circuit depth 5
#
# Max grad 0.029844544505741963
# Epoch = 7, G Energy = -7.61751915 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50533405 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50527554 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50521722 Ha, Sz = -1.00000000
# Number of gates = 7
#
# Circuit depth 6
#
# Max grad 0.027381775104758782
# Epoch = 8, G Energy = -7.61707537 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50651683 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50648765 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50645916 Ha, Sz = -1.00000000
# Number of gates = 8
#
# Circuit depth 7
#
# Max grad 0.027182987080838484
# Epoch = 9, G Energy = -7.61707406 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50725193 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50723967 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50722881 Ha, Sz = -1.00000000
# Number of gates = 9
#
# Circuit depth 8
#
# Max grad 0.025299020638842932
# Epoch = 10, G Energy = -7.61736564 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50770957 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50771190 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50771543 Ha, Sz = -1.00000000
# Number of gates = 10
#
# Circuit depth 9
#
# Max grad 0.021231684967270546
# Epoch = 11, G Energy = -7.61776138 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50799329 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50800441 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50801599 Ha, Sz = -1.00000000
# Number of gates = 11
#
# Circuit depth 10
#
# Max grad 0.018512483129958585
# Epoch = 12, G Energy = -7.61812774 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50816703 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50817999 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50819313 Ha, Sz = -1.00000000
# Number of gates = 12
#
# Circuit depth 11
#
# Max grad 0.014323898459810037
# Epoch = 13, G Energy = -7.61841313 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50827021 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50828534 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50830054 Ha, Sz = -1.00000000
# Number of gates = 13
#
# Circuit depth 12
#
# Max grad 0.010921934957595088
# Epoch = 14, G Energy = -7.61860645 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50832882 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50834870 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50836862 Ha, Sz = -1.00000000
# Number of gates = 14
#
# Circuit depth 13
#
# Max grad 0.008926881767694926
# Epoch = 15, G Energy = -7.61872691 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50835992 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50838713 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50841435 Ha, Sz = -1.00000000
# Number of gates = 15
#
# Circuit depth 14
#
# Max grad 0.007867592969304898
# Epoch = 16, G Energy = -7.61881423 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50837659 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50841088 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50844518 Ha, Sz = -1.00000000
# Number of gates = 16
#
# Circuit depth 15
#
# Max grad 0.0060753896972234305
# Epoch = 17, G Energy = -7.61888193 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50838609 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50842149 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50845731 Ha, Sz = -1.00000000
# Number of gates = 17
#
# Circuit depth 16
#
# Max grad 0.006126642191831693
# Epoch = 18, G Energy = -7.61894807 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50839444 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50842231 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50845465 Ha, Sz = -1.00000000
# Number of gates = 18
#
# Circuit depth 17
#
# Max grad 0.005917865987687691
# Epoch = 19, G Energy = -7.61901732 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50840513 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50841389 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50844073 Ha, Sz = -1.00000000
# Number of gates = 19
#
# Circuit depth 18
#
# Max grad 0.005736389468580102
# Epoch = 20, G Energy = -7.61908317 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50841997 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50840384 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50842667 Ha, Sz = -1.00000000
# Number of gates = 20
#
# Circuit depth 19
#
# Max grad 0.005059355659752494
# Epoch = 21, G Energy = -7.61914219 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50844418 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50839071 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50841267 Ha, Sz = -1.00000000
# Number of gates = 21
#
# Circuit depth 20
#
# Max grad 0.004506159074736904
# Epoch = 22, G Energy = -7.61919738 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50847376 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50836998 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50839635 Ha, Sz = -1.00000000
# Number of gates = 22
#
# Circuit depth 21
#
# Max grad 0.004129682543256697
# Epoch = 23, G Energy = -7.61923925 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50851296 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50836081 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50838454 Ha, Sz = -1.00000000
# Number of gates = 23
#
# Circuit depth 21
#
# Max grad 0.004197899281786698
# Epoch = 24, G Energy = -7.61927316 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50855956 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50836492 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50837496 Ha, Sz = -1.00000000
# Number of gates = 24
#
# Circuit depth 21
#
# Max grad 0.004107359094921172
# Epoch = 25, G Energy = -7.61930160 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50861197 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50838187 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50836638 Ha, Sz = -1.00000000
# Number of gates = 25
#
# Circuit depth 22
#
# Max grad 0.0038756911311437067
# Epoch = 26, G Energy = -7.61932530 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50866858 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50840919 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50835813 Ha, Sz = -1.00000000
# Number of gates = 26
#
# Circuit depth 23
#
# Max grad 0.003832131909106008
# Epoch = 27, G Energy = -7.61934877 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50872287 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50843504 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50834999 Ha, Sz = -1.00000000
# Number of gates = 27
#
# Circuit depth 24
#
# Max grad 0.003203066270537914
# Epoch = 28, G Energy = -7.61936213 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50878345 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50847186 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50834757 Ha, Sz = -1.00000000
# Number of gates = 28
#
# Circuit depth 25
#
# Max grad 0.0029095829348804703
# Epoch = 29, G Energy = -7.61937436 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50884077 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50850548 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50834593 Ha, Sz = -1.00000000
# Number of gates = 29
#
# Circuit depth 26
#
# Max grad 0.002486729019775597
# Epoch = 30, G Energy = -7.61937886 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50890154 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50854550 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50834914 Ha, Sz = -1.00000000
# Number of gates = 30
#
# Circuit depth 27
#
# Max grad 0.0023811739907348274
# Epoch = 31, G Energy = -7.61938357 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50895775 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50858084 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50835255 Ha, Sz = -1.00000000
# Number of gates = 31
#
# Circuit depth 28
#
# Max grad 0.0018282352371535456
# Epoch = 32, G Energy = -7.61938217 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50901581 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50862005 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50836048 Ha, Sz = -1.00000000
# Number of gates = 32
#
# Circuit depth 29
#
# Max grad 0.0020730444823781648
# Epoch = 33, G Energy = -7.61938228 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50906876 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50865433 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50836815 Ha, Sz = -1.00000000
# Number of gates = 33
#
# Circuit depth 30
#
# Max grad 0.0015028178874496965
# Epoch = 34, G Energy = -7.61937896 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50912137 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50868922 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50838048 Ha, Sz = -1.00000000
# Number of gates = 34
#
# Circuit depth 31
#
# Max grad 0.0015513563298137167
# Epoch = 35, G Energy = -7.61937598 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50917088 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50872215 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50839395 Ha, Sz = -1.00000000
# Number of gates = 35
#
# Circuit depth 32
#
# Max grad 0.0015146842522501067
# Epoch = 36, G Energy = -7.61937097 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50921991 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50875630 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50841101 Ha, Sz = -1.00000000
# Number of gates = 36
#
# Circuit depth 33
#
# Max grad 0.0016199248100163192
# Epoch = 37, G Energy = -7.61936806 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50926521 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50878794 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50842748 Ha, Sz = -1.00000000
# Number of gates = 37
#
# Circuit depth 34
#
# Max grad 0.001318133139511709
# Epoch = 38, G Energy = -7.61935996 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50931347 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50882419 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50845031 Ha, Sz = -1.00000000
# Number of gates = 38
#
# Circuit depth 35
#
# Max grad 0.0019572295768557385
# Epoch = 39, G Energy = -7.61935810 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50935466 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50885412 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50846784 Ha, Sz = -1.00000000
# Number of gates = 39
#
# Circuit depth 36
#
# Max grad 0.0010271459804291128
# Epoch = 40, G Energy = -7.61934268 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50940551 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50889520 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50849829 Ha, Sz = -1.00000000
# Number of gates = 40
#
# Circuit depth 37
#
# Max grad 0.003228609949494328
# Epoch = 41, G Energy = -7.61934043 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50943827 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50891816 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50851041 Ha, Sz = -1.00000000
# Number of gates = 41
#
# Circuit depth 38
#
# Max grad 0.0028796008227265396
# Epoch = 42, G Energy = -7.61926929 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50950196 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50897394 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50855850 Ha, Sz = -1.00000000
# Number of gates = 42
#
# Circuit depth 39
#
# Max grad 0.009026425836504629
# Epoch = 43, G Energy = -7.61907232 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50950281 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50896472 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50853796 Ha, Sz = -1.00000000
# Number of gates = 43
#
# Circuit depth 40
#
# Max grad 0.01771445141342216
# Epoch = 44, G Energy = -7.61735181 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50964394 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50910197 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50867441 Ha, Sz = -1.00000000
# Number of gates = 44
#
# Circuit depth 41
#
# Max grad 0.048018642627743996
# Epoch = 45, G Energy = -7.60500428 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50944837 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50888577 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50843508 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.12896787819453132
# Epoch = 46, G Energy = -7.51241399 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51024177 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50968158 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50928000 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.33738376479715115
# Epoch = 47, G Energy = -7.04375098 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50906558 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50830622 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50779935 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.5880487373043403
# Epoch = 48, G Energy = -6.68005512 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51497495 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51382035 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51343673 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.4529275697888943
# Epoch = 49, G Energy = -7.48061871 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51677971 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51463659 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51300963 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.3485942380294947
# Epoch = 50, G Energy = -7.05227876 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51778072 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51534508 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51399581 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.5475548141790032
# Epoch = 51, G Energy = -6.86237271 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51670074 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51308175 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51100244 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.48248057124842875
# Epoch = 52, G Energy = -7.29359220 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52190903 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51563236 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51199071 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.41097222001666917
# Epoch = 53, G Energy = -7.14651193 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51949142 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51261840 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50903906 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.41521869076282614
# Epoch = 54, G Energy = -7.30789281 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52245001 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51246289 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50793966 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.3134195516530944
# Epoch = 55, G Energy = -7.40998404 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52004000 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50975565 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50549437 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2379915962410016
# Epoch = 56, G Energy = -7.46237791 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52173136 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51094507 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50630640 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2042312148118657
# Epoch = 57, G Energy = -7.48546549 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51980595 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50972997 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50549336 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.1903348441151801
# Epoch = 58, G Energy = -7.48812233 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52107901 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51104088 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50679814 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.20395860992777007
# Epoch = 59, G Energy = -7.47827982 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51927006 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50930679 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50545785 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.21996119333172562
# Epoch = 60, G Energy = -7.45964303 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52077505 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51064862 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50679937 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.24168154806598188
# Epoch = 61, G Energy = -7.44724986 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51896235 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50839953 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50477370 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.24550551631992742
# Epoch = 62, G Energy = -7.44888790 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52082807 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51000327 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50618134 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.23777765769900294
# Epoch = 63, G Energy = -7.46492054 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51912230 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50782539 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50413145 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.21504538424929515
# Epoch = 64, G Energy = -7.48198562 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52083029 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50954869 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50563750 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.19983799112055498
# Epoch = 65, G Energy = -7.49481383 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51940462 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50786818 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50414966 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.18630057990391757
# Epoch = 66, G Energy = -7.49914436 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52079009 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50955324 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50571086 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.188719536284097
# Epoch = 67, G Energy = -7.49888720 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51951282 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50798199 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50434153 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.19214360806930453
# Epoch = 68, G Energy = -7.49147231 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52082801 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50968463 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50592605 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2058209207333338
# Epoch = 69, G Energy = -7.48410348 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51954705 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50789877 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50431080 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2136980755287841
# Epoch = 70, G Energy = -7.47545115 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52098384 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50970587 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50594824 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.22195112432008854
# Epoch = 71, G Energy = -7.47522456 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51968596 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50773389 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50411677 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.21817819231020844
# Epoch = 72, G Energy = -7.47751523 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52116247 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50958292 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50575506 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2136712940712322
# Epoch = 73, G Energy = -7.48638334 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51994597 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50772959 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50405473 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2023310526342898
# Epoch = 74, G Energy = -7.49125787 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52128621 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50954280 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50568441 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.19867749112465846
# Epoch = 75, G Energy = -7.49695191 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52019838 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50789744 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50421019 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.1937622808443147
# Epoch = 76, G Energy = -7.49572509 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52139728 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50966513 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50583155 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.1986458797003966
# Epoch = 77, G Energy = -7.49523768 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52036599 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50802660 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50435446 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.20134728598106663
# Epoch = 78, G Energy = -7.48894690 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52152891 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50979370 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50598722 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.20989993176320224
# Epoch = 79, G Energy = -7.48700172 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52049976 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50802939 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50436244 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.21231351711723226
# Epoch = 80, G Energy = -7.48211652 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52167775 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50980697 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50600620 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.21613496409460123
# Epoch = 81, G Energy = -7.48513578 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52066877 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50798953 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50431234 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.21220793582181802
# Epoch = 82, G Energy = -7.48504592 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52181107 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50974441 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50594580 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.21084050292043263
# Epoch = 83, G Energy = -7.49125023 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52087375 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50802914 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50434738 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2048084269758618
# Epoch = 84, G Energy = -7.49136824 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52192481 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50974602 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50596983 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2049811554168038
# Epoch = 85, G Energy = -7.49541954 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52106480 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50813758 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50446417 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.20273213135091797
# Epoch = 86, G Energy = -7.49232916 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52203440 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50982352 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50608308 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.20696764397854533
# Epoch = 87, G Energy = -7.49358453 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52121645 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50821593 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50455382 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.20795205081150336
# Epoch = 88, G Energy = -7.48848102 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52214334 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50988241 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50617775 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.21303934442266015
# Epoch = 89, G Energy = -7.49000306 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52135038 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50822924 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50457614 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.21300848342493078
# Epoch = 90, G Energy = -7.48607002 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52224570 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50987053 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50620090 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.21540010613867075
# Epoch = 91, G Energy = -7.49015827 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52149273 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50822719 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50458563 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2125250855868558
# Epoch = 92, G Energy = -7.48806590 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52233640 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50983329 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50620418 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2130146354668415
# Epoch = 93, G Energy = -7.49318266 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52164262 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50826480 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50464004 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2097844586274206
# Epoch = 94, G Energy = -7.49079257 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52241961 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50983629 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50625366 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.21131168221648086
# Epoch = 95, G Energy = -7.49477130 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52178180 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50833031 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50472324 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.20998510110675178
# Epoch = 96, G Energy = -7.49085278 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52249790 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50987040 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50633665 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2131985228919454
# Epoch = 97, G Energy = -7.49380334 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.
Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52288782 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50856729 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50563107 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.23241658200330187
# Epoch = 132, G Energy = -7.49262116 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52270837 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50953381 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50731986 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.23405321646355576
# Epoch = 133, G Energy = -7.49824449 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52288482 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50855263 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50567715 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.23374298589771852
# Epoch = 134, G Energy = -7.49288617 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52265977 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50949903 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50737670 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.23536982268595247
# Epoch = 135, G Energy = -7.49854172 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52287551 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50853514 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50572268 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.23511997400438317
# Epoch = 136, G Energy = -7.49313685 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52260548 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50946331 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50743391 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.23674587480443024
# Epoch = 137, G Energy = -7.49882001 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52285995 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50851434 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50576726 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2365506265822988
# Epoch = 138, G Energy = -7.49337862 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52254556 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50942614 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50749108 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.23816626348155773
# Epoch = 139, G Energy = -7.49909495 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52283822 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50848992 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50581076 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.23801069198395272
# Epoch = 140, G Energy = -7.49363082 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52248013 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50938736 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50754809 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.23960809421548177
# Epoch = 141, G Energy = -7.49938041 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52281040 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50846205 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50585330 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.2394853241226032
# Epoch = 142, G Energy = -7.49390139 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52240932 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50934724 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50760506 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.24106668057605263
# Epoch = 143, G Energy = -7.49967615 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52277661 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50843097 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50589501 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.24097881866479173
# Epoch = 144, G Energy = -7.49418498 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52233328 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50930604 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50766212 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.24255112880180524
# Epoch = 145, G Energy = -7.49997520 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52273697 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50839681 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50593584 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.24250106347895056
# Epoch = 146, G Energy = -7.49447478 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52225217 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50926386 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50771927 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.24406886274486686
# Epoch = 147, G Energy = -7.50027394 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52269161 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50835953 Ha, Sz= 0.00000000
# ...
#
# Max grad 0.11863433128438125
# Epoch = 352, G Energy = -7.61290606 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52142126 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51634248 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51312740 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.12138694092363367
# Epoch = 353, G Energy = -7.61366626 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52144346 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51552317 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51233582 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11761411388152933
# Epoch = 354, G Energy = -7.61313076 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52141608 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51638312 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51317376 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.1203850387426682
# Epoch = 355, G Energy = -7.61387178 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52143692 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51557640 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51239813 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11666673464779252
# Epoch = 356, G Energy = -7.61333847 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52141080 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51642331 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51321994 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.1194544694980357
# Epoch = 357, G Energy = -7.61406135 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52143034 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51562857 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51245957 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11578947532554915
# Epoch = 358, G Energy = -7.61353010 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52140542 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51646307 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51326591 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11859253676026282
# Epoch = 359, G Energy = -7.61423585 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52142371 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51567973 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51252016 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11497960907852349
# Epoch = 360, G Energy = -7.61370654 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52139996 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51650238 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51331165 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11779653377503552
# Epoch = 361, G Energy = -7.61439612 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52141705 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51572991 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51257989 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11423440005940971
# Epoch = 362, G Energy = -7.61386863 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52139443 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51654126 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51335714 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11706374298651961
# Epoch = 363, G Energy = -7.61454295 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52141037 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51577913 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51263878 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11355110276481467
# Epoch = 364, G Energy = -7.61401717 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52138885 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51657971 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51340236 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11639143539803704
# Epoch = 365, G Energy = -7.61467711 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52140368 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51582743 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51269684 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11292696129363569
# Epoch = 366, G Energy = -7.61415295 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52138323 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51661772 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51344729 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11577686988520887
# Epoch = 367, G Energy = -7.61479933 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52139698 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51587484 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51275408 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.1123592086213439
# Epoch = 368, G Energy = -7.61427672 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52137758 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51665531 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51349191 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.1152172925728761
# Epoch = 369, G Energy = -7.61491033 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52139028 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51592137 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51281051 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11184506599872668
# Epoch = 370, G Energy = -7.61438918 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52137189 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51669246 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51353620 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11470993638284135
# Epoch = 371, G Energy = -7.61501078 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52138359 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51596705 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51286615 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11138174257903766
# Epoch = 372, G Energy = -7.61449103 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52136620 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51672919 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51358015 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11425202085446089
# Epoch = 373, G Energy = -7.61510136 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52137691 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51601191 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51292100 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11096643537208704
# Epoch = 374, G Energy = -7.61458297 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52136049 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51676549 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51362375 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11384075233421434
# Epoch = 375, G Energy = -7.61518271 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52137025 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51605598 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51297507 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11059632961738029
# Epoch = 376, G Energy = -7.61466563 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52135478 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51680136 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51366697 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.1134733246233059
# Epoch = 377, G Energy = -7.61525545 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52136361 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51609927 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51302839 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11026859966074126
# Epoch = 378, G Energy = -7.61473967 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52134907 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51683680 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51370981 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11314692016408258
# Epoch = 379, G Energy = -7.61532021 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52135700 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51614182 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51308095 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.1099804104098846
# Epoch = 380, G Energy = -7.61480572 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52134337 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51687181 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51375225 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11285871183629621
# Epoch = 381, G Energy = -7.61537758 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52135041 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51618363 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51313278 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.10972891943390783
# Epoch = 382, G Energy = -7.61486439 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52133769 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51690639 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51379429 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11260586542300373
# Epoch = 383, G Energy = -7.61542814 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52134387 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51622474 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51318389 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.10951127975969344
# Epoch = 384, G Energy = -7.61491629 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52133202 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51694054 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51383591 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11238554279318604
# Epoch = 385, G Energy = -7.61547249 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52133736 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51626516 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51323428 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.10932464340477142
# Epoch = 386, G Energy = -7.61496201 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52132638 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51697425 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51387711 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11219490583393274
# Epoch = 387, G Energy = -7.61551120 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52133089 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51630492 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51328398 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.10916616567114029
# Epoch = 388, G Energy = -7.61500215 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52132077 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51700754 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51391787 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11203112114935518
# Epoch = 389, G Energy = -7.61554481 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52132447 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51634403 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51333299 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.10903301020843953
# Epoch = 390, G Energy = -7.61503727 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52131518 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51704038 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51395818 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11189136552669823
# Epoch = 391, G Energy = -7.61557389 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52131809 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51638252 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51338133 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.1089223548374935
# Epoch = 392, G Energy = -7.61506794 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52130963 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51707280 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51399805 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11177283215224382
# Epoch = 393, G Energy = -7.61559898 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52131176 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51642040 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51342901 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.10883139810714736
# Epoch = 394, G Energy = -7.61509473 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52130412 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51710477 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51403747 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11167273754133065
# Epoch = 395, G Energy = -7.61562061 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52130548 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51645769 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51347605 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.10875736653890533
# Epoch = 396, G Energy = -7.61511819 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52129864 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51713631 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51407643 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11158832912817691
# Epoch = 397, G Energy = -7.61563931 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52129925 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51649442 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51352246 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.10869752249534644
# Epoch = 398, G Energy = -7.61513884 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52129321 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51716742 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51411493 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.11151689344297042
# Epoch = 399, G Energy = -7.61565559 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52129308 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51653059 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51356825 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
#
# Max grad 0.1086491725904727
# Epoch = 400, G Energy = -7.61515724 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52128782 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51719809 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51415296 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 42
