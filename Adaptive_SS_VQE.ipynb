# %%
# !pip install pennylane
# Out:
# Requirement already satisfied: pennylane in /usr/local/lib/python3.10/dist-packages (0.34.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.11.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.2.1)
# Requirement already satisfied: rustworkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.14.0)
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.6.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.4.4)
# Requirement already satisfied: semantic-version>=2.7 in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.10.0)
# Requirement already satisfied: autoray>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.6.8)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.3.2)
# Requirement already satisfied: pennylane-lightning>=0.34 in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.34.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.9.0)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2024.2.2)

# %%
import pennylane as qml
import pennylane.numpy as np
import matplotlib.pyplot as plt

# %%
def hydrogen_hamiltonian(coordinates):
    """Calculates the qubit Hamiltonian of the hydrogen molecule.

    Args:
        coordinates (list(float)): Cartesian coordinates of each hydrogen molecule.
        charge (int): The electric charge given to the hydrogen molecule.

    Returns:
        (qml.Hamiltonian): A PennyLane Hamiltonian.
    """
    return qml.qchem.molecular_hamiltonian(["H", "Li"], coordinates, charge=0, basis="STO-3G",active_electrons=2)[0]


def hf(electrons, num_qubits):
    """Calculates the Hartree-Fock state of the hydrogen molecule.

    Args:
        electrons (int): The number of electrons in the hydrogen molecule.
        num_qubits (int): The number of qubits needed to represent the hydrogen molecule Hamiltonian.

    Returns:
        (numpy.tensor): The HF state.
    """
    # Put your solution here #
    return qml.qchem.hf_state(electrons=electrons, orbitals=num_qubits)

# %%
def num_electrons(charge):
    """The total number of electrons in the hydrogen molecule.

    Args:
        charge (int): The electric charge given to the hydrogen molecule.

    Returns:
        (int): The number of electrons.
    """
    return 3-charge

# %%
def depth(qnode):
    def _fn(*args, **kwargs):
        qnode.construct(args, kwargs)
        return qnode.qtape.get_depth()
    return _fn

# %% [markdown]
# Using exact diagonalization to get the ground state and first excited state.

# %%
L=1.5
coordinates = np.array([0.0, 0.0, -L/2, 0.0, 0.0, L/2]) #np.array([-L/2/np.sqrt(3), L/2, 0.0, L/np.sqrt(3), 0.0, 0.0,-L/2/np.sqrt(3), -L/2, 0.0])
charge=0
hamiltonian = hydrogen_hamiltonian(np.array(coordinates))
H_matrix=qml.matrix(hamiltonian)

# %%
vals, vecs = np.linalg.eigh(H_matrix)

inds=np.argsort(vals)
eng=vals[inds]
vec=vecs[:,inds]

print('The ground state energy:',eng[0])
# Out:
# The ground state energy: -7.626624465547493

# %%
def vec_check(vec,electron_num):
    for i,e in enumerate(vec):
        if np.abs(e) > 1e-8:
            e_occ=bin(i)[2:]
            lst=' '.join(e_occ).split(' ')
            cv=tuple(map(int, lst))
            e_num=sum(cv)
            if e_num!=electron_num:
                return False
    return True

# %%
sz=qml.qchem.spinz(len(hamiltonian.wires))
SZ=qml.matrix(sz)
Stop=[False,False,False]
elec_num=2
for i in range(1,len(eng)): # Finding first excited state with -1 Sz
    Sz=vec[:,i].dot(SZ.dot(np.transpose(np.conjugate(vec[:,i]))))
    #print(Sz)

    if np.abs(Sz) < 1e-5 and vec_check(vec[:,i],elec_num):
        print('The first excied state energy with sz=0:',eng[i])
        #Stop[0]=True
        break
# Out:
# The first excied state energy with sz=0: -7.522914627103034

# %%
vec[:,i]
# Out:
# array([ 0.00000000e+00+0.j,  1.05866753e-29+0.j, -6.07190299e-17+0.j, ...,
#         0.00000000e+00+0.j,  0.00000000e+00+0.j,  0.00000000e+00+0.j])

# %%
electrons = 2
num_qubits = len(hamiltonian.wires)

S2 = qml.qchem.spin2(electrons, num_qubits)
sz=qml.qchem.spinz(num_qubits)

singles, doubles = qml.qchem.excitations(electrons, num_qubits)
pool_operators=singles+doubles

num_qubits = len(hamiltonian.wires)
hf_state = hf(electrons, num_qubits)

dev = qml.device("default.qubit", wires=num_qubits)
print("The original vqe use ",len(doubles)*13 + len(singles)*2," cnot gates")
print("The original vqe use ",len(doubles)*34 + len(singles)*10," gates")

bitstr=''.join(map(str, hf_state))

g_trial_stat={bitstr: 1}
e_trial_stat_szp1={'1010000000': 1}
e_trial_stat_szm1={'0101000000': 1}
e_trial_stat_sz0={'1001000000': 1,'0110000000': 1}

def bit_to_vec(bitstring_dict,num_qubits):
    vec=np.zeros(2**num_qubits)
    amp=0
    for i in range(2**num_qubits):
        bitstr=bin(i)[2:]
        if len(bitstr) < num_qubits:
            bitstr=(num_qubits-len(bitstr))*'0'+bitstr
        #print(bitstr)
        if bitstr in bitstring_dict:
            vec[i]=bitstring_dict[bitstr]
            amp+=np.abs(bitstring_dict[bitstr])**2
    vec=vec/np.sqrt(amp)
    return vec

g_stat=bit_to_vec(g_trial_stat,num_qubits)
e_stat_szp1=bit_to_vec(e_trial_stat_szp1,num_qubits)
e_stat_szm1=bit_to_vec(e_trial_stat_szm1,num_qubits)
e_stat_sz0=bit_to_vec(e_trial_stat_sz0,num_qubits)

def circuit(state,weights):
    qml.StatePrep(state, wires=range(num_qubits))
    for i in range(len(singles)):
        qml.SingleExcitation(weights[i+len(doubles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(weights[i], wires=doubles[i])

    for i in range(len(singles)):
        qml.SingleExcitation(weights[i+2*len(doubles)+len(singles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(weights[i+len(doubles)+len(singles)], wires=doubles[i])

    return qml.expval(hamiltonian)

def circuit_sz(state,weights):
    qml.StatePrep(state, wires=range(num_qubits))
    for i in range(len(singles)):
        qml.SingleExcitation(weights[i+len(doubles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(weights[i], wires=doubles[i])

    for i in range(len(singles)):
        qml.SingleExcitation(weights[i+2*len(doubles)+len(singles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(weights[i+len(doubles)+len(singles)], wires=doubles[i])
    return qml.expval(sz)


cost_h_fn = qml.QNode(circuit, dev)
Sz_fn = qml.QNode(circuit_sz, dev)

def cost_fn(params):
    return cost_h_fn(g_stat,params)+0.5*cost_h_fn(e_stat_szp1,params)+0.5*cost_h_fn(e_stat_szm1,params)\
            +0.5*cost_h_fn(e_stat_sz0,params)

weights =np.zeros(2*len(doubles + singles), requires_grad=True)

opt = qml.AdamOptimizer(stepsize=0.5)

i=0
iter=[]
cost_val=[]
Lowest_E=0
best_weights=0

cov=1e-5
E0_pev=0
E1_pev=0
E2_pev=0
E3_pev=0

for _ in range(400):
    weights = opt.step(cost_fn, weights)
    iter.append(i)

    E0=cost_h_fn(g_stat,weights)
    E1=cost_h_fn(e_stat_szp1,weights)
    E2=cost_h_fn(e_stat_sz0,weights)
    E3=cost_h_fn(e_stat_szm1,weights)

    if Lowest_E>E0:
        Lowest_E=E0
        best_weights=weights
    cost_val.append(E0)

    i=i+1
    print('Need iter:',i,' E0:',E0,', E1:',E1,' Sz:',Sz_fn(e_stat_szp1,weights))
    print('E2:',E2,Sz_fn(e_stat_sz0,weights))
    print('E3:',E3,Sz_fn(e_stat_szm1,weights))
    if np.abs(E0-E0_pev)<cov and np.abs(E1-E1_pev)<cov and np.abs(E2-E2_pev)<cov and np.abs(E3-E3_pev)<cov:
        print('Need iter:',i,' E0:',E0,', E1:',E1,' Sz:',Sz_fn(e_stat_szp1,weights))
        print('E2:',E2,Sz_fn(e_stat_sz0,weights))
        print('E3:',E3,Sz_fn(e_stat_szm1,weights))
        break

    E0_pev=E0
    E1_pev=E1
    E2_pev=E2
    E3_pev=E3
# Out:
# The original vqe use  224  cnot gates
# The original vqe use  624  gates
# Need iter: 1  E0: -7.114361086861115 , E1: -7.464140817197321  Sz: 1.0
# E2: -7.4639406502334085 -8.326672684688674e-17
# E3: -7.464032961677203 -1.0
# Need iter: 2  E0: -7.206854536072497 , E1: -7.49408793966439  Sz: 1.0
# E2: -7.495944851828021 5.551115123125783e-17
# E3: -7.498316375839986 -1.0
# Need iter: 3  E0: -7.403765724131152 , E1: -7.510131345584048  Sz: 1.0
# E2: -7.500083460776256 0.0
# E3: -7.513275162000521 -1.0
# Need iter: 4  E0: -7.388160843037501 , E1: -7.515238978025504  Sz: 0.9999999999999997
# E2: -7.510460289070379 -2.7755575615628914e-17
# E3: -7.516227935536564 -0.9999999999999997
# Need iter: 5  E0: -7.473409277364713 , E1: -7.49417707357977  Sz: 0.9999999999999999
# E2: -7.500834585541014 0.0
# E3: -7.50596459664734 -1.0
# Need iter: 6  E0: -7.463527924576138 , E1: -7.493139935867371  Sz: 1.0
# E2: -7.496506836570258 0.0
# E3: -7.509698517436156 -0.9999999999999998
# Need iter: 7  E0: -7.402949539510246 , E1: -7.50729549662927  Sz: 0.9999999999999997
# E2: -7.505811953239703 5.551115123125783e-17
# E3: -7.515795095778095 -1.0
# Need iter: 8  E0: -7.445959856973898 , E1: -7.5167697132543045  Sz: 1.0
# E2: -7.512838742582188 0.0
# E3: -7.517181314165187 -1.0000000000000002
# E2: -7.522675891620736 2.7755575615628914e-17
# E3: -7.522610387109784 -0.9999999999999998
# Need iter: 219  E0: -7.626452453168302 , E1: -7.522913312271245  Sz: 1.0
# E2: -7.522692434148879 0.0
# E3: -7.5226104708314745 -1.0
# Need iter: 220  E0: -7.626448487785835 , E1: -7.522913369163414  Sz: 0.9999999999999999
# E2: -7.522706703870438 -5.551115123125783e-17
# E3: -7.5226100514641 -1.0
# Need iter: 221  E0: -7.626444757967218 , E1: -7.522913152620722  Sz: 0.9999999999999999
# E2: -7.5227192511093754 2.7755575615628914e-17
# E3: -7.522609184137246 -1.0
# Need iter: 222  E0: -7.626441269168077 , E1: -7.522912729831648  Sz: 1.0000000000000002
# E2: -7.5227300681477205 -5.551115123125783e-17
# E3: -7.522608180402212 -1.0
# Need iter: 223  E0: -7.626438284825401 , E1: -7.522912145739957  Sz: 0.9999999999999998
# E2: -7.5227386690911295 2.7755575615628914e-17
# E3: -7.522607302603256 -1.0
# Need iter: 223  E0: -7.626438284825401 , E1: -7.522912145739957  Sz: 0.9999999999999998
# E2: -7.5227386690911295 2.7755575615628914e-17
# E3: -7.522607302603256 -1.0

# %%
electrons = 2
num_qubits = len(hamiltonian.wires)

singles, doubles = qml.qchem.excitations(electrons, num_qubits)
pool_operators=singles+doubles

num_qubits = len(hamiltonian.wires)
hf_state = hf(electrons, num_qubits)

def circuit_1(state,weights,excitations):
    qml.StatePrep(state, wires=range(num_qubits))
    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(weights[i], wires=excitation)
        else:
            qml.SingleExcitation(weights[i], wires=excitation)
    return qml.expval(hamiltonian)

def circuit_sz(state,weights,excitations):
    qml.StatePrep(state, wires=range(num_qubits))
    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(weights[i], wires=excitation)
        else:
            qml.SingleExcitation(weights[i], wires=excitation)
    return qml.expval(sz)

dev = qml.device("default.qubit", wires=num_qubits)#

cost_h_fn = qml.QNode(circuit_1, dev, expansion_strategy="device")
Sz_fn = qml.QNode(circuit_sz, dev)

def cost_fn(params, excitations):
    return cost_h_fn(g_stat,params, excitations)+0.45*cost_h_fn(e_stat_szp1,params, excitations)\
            +0.45*cost_h_fn(e_stat_szm1,params, excitations)+0.2*cost_h_fn(e_stat_sz0,params, excitations)


epochs=200

energy=[]
operator_circuits=[]# doubles_select+singles_select

weights = [] #[0.0] * len(operator_circuits)
weights=np.array(weights)

opt = opt = qml.GradientDescentOptimizer(stepsize=0.25)

circuit_gradient = qml.grad(cost_fn, argnum=0)


E0 = cost_h_fn(g_stat,weights, operator_circuits)
E1 = cost_h_fn(e_stat_szp1,weights, operator_circuits)
E2 = cost_h_fn(e_stat_sz0,weights, operator_circuits)
E3 = cost_h_fn(e_stat_szm1,weights, operator_circuits)

print(f"Epoch = 0, G Energy = {E0:.8f} Ha, E1 Energy = {E1:.8f} Ha,")
print(f" E2 Energy = {E1:.8f} Ha")
print("Number of gates = {}\n".format(len(operator_circuits)))

configs=qml.specs(cost_h_fn)(g_stat,weights, excitations=operator_circuits)

#print(configs)
print("Circuit depth {}\n".format(configs['resources'].depth))

conv=1e-7
E0_pev=0
E1_pev=0
E2_pev=0
E3_pev=0
for n in range(epochs):

    Test_set=operator_circuits+pool_operators
    Test_params=list(weights)+[0.0]*len(pool_operators)
    Test_params=np.array(Test_params)

    test_grads = circuit_gradient(Test_params,Test_set)
    test_grads = test_grads[len(weights):]
    maxpos = np.argmax(np.abs(test_grads))

    max_op=pool_operators[maxpos]
    operator_circuits.append(max_op)
    weights=np.append(weights, 0.0)

    weights,_ = opt.step(cost_fn, weights, operator_circuits) # Step 11.
    E0 = cost_h_fn(g_stat,weights,operator_circuits)
    E1 = cost_h_fn(e_stat_szp1,weights, operator_circuits)
    E2 = cost_h_fn(e_stat_sz0,weights, operator_circuits)
    E3 = cost_h_fn(e_stat_szm1,weights, operator_circuits)

    print(f"Epoch = {n+1}, G Energy = {E0:.8f} Ha, Sz = {Sz_fn(g_stat,weights,operator_circuits):.8f} Ha,")
    print(f" The first excited state Energy = {E1:.8f} Ha, Sz= {Sz_fn(e_stat_szp1,weights,operator_circuits):.8f}")
    print(f" The first excited state Energy = {E2:.8f} Ha, Sz= {Sz_fn(e_stat_sz0,weights,operator_circuits):.8f}")
    print(f" The first excited state Energy = {E3:.8f} Ha, Sz = {Sz_fn(e_stat_szm1,weights,operator_circuits):.8f}")
    print("Number of gates = {}\n".format(len(operator_circuits)))
    configs=qml.specs(cost_h_fn)(g_stat,weights, excitations=operator_circuits)
    print("Circuit depth {}\n".format(configs['resources'].depth))

    if np.abs(E0-E0_pev)<cov and np.abs(E1-E1_pev)<cov and np.abs(E3-E3_pev)<cov:
        break

    E0_pev=E0
    E1_pev=E1
    E2_pev=E2
    E3_pev=E3
# Out:
# Epoch = 0, G Energy = -7.60898166 Ha, E1 Energy = -7.49074895 Ha,
#  E2 Energy = -7.49074895 Ha
# Number of gates = 0
#
# Circuit depth 1
#
# Epoch = 1, G Energy = -7.61248262 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.49074895 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.49074895 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.49074895 Ha, Sz = -1.00000000
# Number of gates = 1
#
# Circuit depth 2
#
# Epoch = 2, G Energy = -7.61715784 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.49074895 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.49074895 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.49074895 Ha, Sz = -1.00000000
# Number of gates = 2
#
# Circuit depth 3
#
# Epoch = 3, G Energy = -7.62030985 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.49074895 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.49074895 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.49074895 Ha, Sz = -1.00000000
# Number of gates = 3
#
# Circuit depth 4
#
# Epoch = 4, G Energy = -7.62122039 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.49074895 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.49194644 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.49314622 Ha, Sz = -1.00000000
# Number of gates = 4
#
# Circuit depth 5
#
# Epoch = 5, G Energy = -7.62134276 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.49313934 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.49416376 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.49519000 Ha, Sz = -1.00000000
# Number of gates = 5
#
# Circuit depth 5
#
# Epoch = 6, G Energy = -7.62094912 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.49713675 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.49703802 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.49693930 Ha, Sz = -1.00000000
# Number of gates = 6
#
# Circuit depth 6
#
# Epoch = 7, G Energy = -7.62009218 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50001737 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.49995537 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.49989337 Ha, Sz = -1.00000000
# Number of gates = 7
#
# Circuit depth 6
#
# Epoch = 8, G Energy = -7.61889118 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50211982 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50259788 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50307653 Ha, Sz = -1.00000000
# Number of gates = 8
#
# Circuit depth 7
#
# Epoch = 9, G Energy = -7.61758373 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50442054 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50472741 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50503455 Ha, Sz = -1.00000000
# Number of gates = 9
#
# Circuit depth 7
#
# Epoch = 10, G Energy = -7.61678815 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50585844 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50606282 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50626745 Ha, Sz = -1.00000000
# Number of gates = 10
#
# Circuit depth 8
#
# Epoch = 11, G Energy = -7.61641148 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50677886 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50691708 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50705571 Ha, Sz = -1.00000000
# Number of gates = 11
#
# Circuit depth 9
#
# Epoch = 12, G Energy = -7.61637447 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50737390 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50747023 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50756727 Ha, Sz = -1.00000000
# Number of gates = 12
#
# Circuit depth 10
#
# Epoch = 13, G Energy = -7.61657685 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50775945 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50783141 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50790400 Ha, Sz = -1.00000000
# Number of gates = 13
#
# Circuit depth 11
#
# Epoch = 14, G Energy = -7.61692454 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50800876 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50806464 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50812110 Ha, Sz = -1.00000000
# Number of gates = 14
#
# Circuit depth 12
#
# Epoch = 15, G Energy = -7.61731594 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50816749 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50821484 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50826248 Ha, Sz = -1.00000000
# Number of gates = 15
#
# Circuit depth 13
#
# Epoch = 16, G Energy = -7.61769393 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50826673 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50830804 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50834949 Ha, Sz = -1.00000000
# Number of gates = 16
#
# Circuit depth 14
#
# Epoch = 17, G Energy = -7.61802370 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50832631 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50836509 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50840392 Ha, Sz = -1.00000000
# Number of gates = 17
#
# Circuit depth 15
#
# Epoch = 18, G Energy = -7.61828461 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50835971 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50839943 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50843923 Ha, Sz = -1.00000000
# Number of gates = 18
#
# Circuit depth 16
#
# Epoch = 19, G Energy = -7.61847502 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50837997 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50842098 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50846217 Ha, Sz = -1.00000000
# Number of gates = 19
#
# Circuit depth 17
#
# Epoch = 20, G Energy = -7.61860303 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50839416 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50843557 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50847725 Ha, Sz = -1.00000000
# Number of gates = 20
#
# Circuit depth 18
#
# Epoch = 21, G Energy = -7.61869496 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50840309 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50844550 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50848822 Ha, Sz = -1.00000000
# Number of gates = 21
#
# Circuit depth 19
#
# Epoch = 22, G Energy = -7.61876925 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50840875 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50845228 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50849617 Ha, Sz = -1.00000000
# Number of gates = 22
#
# Circuit depth 20
#
# Epoch = 23, G Energy = -7.61882838 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50841253 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50845695 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50850173 Ha, Sz = -1.00000000
# Number of gates = 23
#
# Circuit depth 21
#
# Epoch = 24, G Energy = -7.61887662 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50841536 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50845746 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50850014 Ha, Sz = -1.00000000
# Number of gates = 24
#
# Circuit depth 22
#
# Epoch = 25, G Energy = -7.61892281 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50841905 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50845454 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50849225 Ha, Sz = -1.00000000
# Number of gates = 25
#
# Circuit depth 23
#
# Epoch = 26, G Energy = -7.61897070 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50842478 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50844803 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50847901 Ha, Sz = -1.00000000
# Number of gates = 26
#
# Circuit depth 24
#
# Epoch = 27, G Energy = -7.61901754 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50843329 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50844166 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50846655 Ha, Sz = -1.00000000
# Number of gates = 27
#
# Circuit depth 25
#
# Epoch = 28, G Energy = -7.61906264 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50844763 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50843451 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50845404 Ha, Sz = -1.00000000
# Number of gates = 28
#
# Circuit depth 26
#
# Epoch = 29, G Energy = -7.61910773 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50846599 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50842374 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50844005 Ha, Sz = -1.00000000
# Number of gates = 29
#
# Circuit depth 27
#
# Epoch = 30, G Energy = -7.61915172 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50848756 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50840822 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50842466 Ha, Sz = -1.00000000
# Number of gates = 30
#
# Circuit depth 28
#
# Epoch = 31, G Energy = -7.61919042 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50851180 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50839361 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50841239 Ha, Sz = -1.00000000
# Number of gates = 31
#
# Circuit depth 29
#
# Epoch = 32, G Energy = -7.61921998 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50854405 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50838927 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50840568 Ha, Sz = -1.00000000
# Number of gates = 32
#
# Circuit depth 30
#
# Epoch = 33, G Energy = -7.61924546 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50858136 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50839374 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50840103 Ha, Sz = -1.00000000
# Number of gates = 33
#
# Circuit depth 31
#
# Epoch = 34, G Energy = -7.61926841 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50862261 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50840645 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50839719 Ha, Sz = -1.00000000
# Number of gates = 34
#
# Circuit depth 32
#
# Epoch = 35, G Energy = -7.61928918 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50866708 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50842647 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50839362 Ha, Sz = -1.00000000
# Number of gates = 35
#
# Circuit depth 33
#
# Epoch = 36, G Energy = -7.61930763 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50871406 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50845230 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50839010 Ha, Sz = -1.00000000
# Number of gates = 36
#
# Circuit depth 34
#
# Epoch = 37, G Energy = -7.61932345 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50876277 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50848216 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50838660 Ha, Sz = -1.00000000
# Number of gates = 37
#
# Circuit depth 35
#
# Epoch = 38, G Energy = -7.61933885 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50880952 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50850959 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50838318 Ha, Sz = -1.00000000
# Number of gates = 38
#
# Circuit depth 36
#
# Epoch = 39, G Energy = -7.61934854 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50885935 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50854182 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50838294 Ha, Sz = -1.00000000
# Number of gates = 39
#
# Circuit depth 37
#
# Epoch = 40, G Energy = -7.61935741 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50890708 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50857159 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50838347 Ha, Sz = -1.00000000
# Number of gates = 40
#
# Circuit depth 38
#
# Epoch = 41, G Energy = -7.61936314 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50895467 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50860146 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50838706 Ha, Sz = -1.00000000
# Number of gates = 41
#
# Circuit depth 39
#
# Epoch = 42, G Energy = -7.61936632 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50900184 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50863147 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50839340 Ha, Sz = -1.00000000
# Number of gates = 42
#
# Circuit depth 40
#
# Epoch = 43, G Energy = -7.61936635 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50904991 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50866386 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50840204 Ha, Sz = -1.00000000
# Number of gates = 43
#
# Circuit depth 41
#
# Epoch = 44, G Energy = -7.61936667 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50909544 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50869406 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50841108 Ha, Sz = -1.00000000
# Number of gates = 44
#
# Circuit depth 42
#
# Epoch = 45, G Energy = -7.61936506 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50914059 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50872454 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50842273 Ha, Sz = -1.00000000
# Number of gates = 45
#
# Circuit depth 43
#
# Epoch = 46, G Energy = -7.61936289 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50918443 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50875445 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50843580 Ha, Sz = -1.00000000
# Number of gates = 46
#
# Circuit depth 44
#
# Epoch = 47, G Energy = -7.61935973 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50922754 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50878445 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50845074 Ha, Sz = -1.00000000
# Number of gates = 47
#
# Circuit depth 45
#
# Epoch = 48, G Energy = -7.61935625 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50926957 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50881420 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50846694 Ha, Sz = -1.00000000
# Number of gates = 48
#
# Circuit depth 46
#
# Epoch = 49, G Energy = -7.61935212 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50931096 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50884431 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50848471 Ha, Sz = -1.00000000
# Number of gates = 49
#
# Circuit depth 47
#
# Epoch = 50, G Energy = -7.61934864 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.50935085 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50887368 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50850286 Ha, Sz = -1.00000000
# Number of gates = 50
#
# Circuit depth 48
#
# Epoch = 51, G Energy = -7.61934315 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50939167 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50890495 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50852385 Ha, Sz = -1.00000000
# Number of gates = 51
#
# Circuit depth 49
#
# Epoch = 52, G Energy = -7.61933993 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50942985 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50893417 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50854356 Ha, Sz = -1.00000000
# Number of gates = 52
#
# Circuit depth 50
#
# Epoch = 53, G Energy = -7.61933243 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50947114 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50896736 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50856811 Ha, Sz = -1.00000000
# Number of gates = 53
#
# Circuit depth 51
#
# Epoch = 54, G Energy = -7.61933047 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50950698 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50899541 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50858793 Ha, Sz = -1.00000000
# Number of gates = 54
#
# Circuit depth 52
#
# Epoch = 55, G Energy = -7.61933087 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50952841 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50902125 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50861733 Ha, Sz = -1.00000000
# Number of gates = 55
#
# Circuit depth 53
#
# Epoch = 56, G Energy = -7.61934053 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50954263 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50903655 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50863326 Ha, Sz = -1.00000000
# Number of gates = 56
#
# Circuit depth 54
#
# Epoch = 57, G Energy = -7.61931211 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50958786 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50907841 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50867224 Ha, Sz = -1.00000000
# Number of gates = 57
#
# Circuit depth 55
#
# Epoch = 58, G Energy = -7.61928937 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50958997 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50907975 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50867283 Ha, Sz = -1.00000000
# Number of gates = 58
#
# Circuit depth 56
#
# Epoch = 59, G Energy = -7.61899084 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50968114 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50916247 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50874880 Ha, Sz = -1.00000000
# Number of gates = 59
#
# Circuit depth 57
#
# Epoch = 60, G Energy = -7.61786312 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50959508 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50908228 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50867380 Ha, Sz = -1.00000000
# Number of gates = 60
#
# Circuit depth 58
#
# Epoch = 61, G Energy = -7.61028653 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50991005 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50936914 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50893953 Ha, Sz = -1.00000000
# Number of gates = 61
#
# Circuit depth 59
#
# Epoch = 62, G Energy = -7.56435230 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50933850 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50883599 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50844982 Ha, Sz = -1.00000000
# Number of gates = 62
#
# Circuit depth 60
#
# Epoch = 63, G Energy = -7.28455696 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51124136 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51052776 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51003916 Ha, Sz = -1.00000000
# Number of gates = 63
#
# Circuit depth 61
#
# Epoch = 64, G Energy = -6.63237609 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.50964747 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50887670 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50849078 Ha, Sz = -1.00000000
# Number of gates = 64
#
# Circuit depth 62
#
# Epoch = 65, G Energy = -7.50084679 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51791053 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51601865 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51453074 Ha, Sz = -1.00000000
# Number of gates = 65
#
# Circuit depth 63
#
# Epoch = 66, G Energy = -6.97595860 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51397455 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51247403 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51154034 Ha, Sz = -1.00000000
# Number of gates = 66
#
# Circuit depth 64
#
# Epoch = 67, G Energy = -6.62345965 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51942081 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51686094 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51529855 Ha, Sz = -1.00000000
# Number of gates = 67
#
# Circuit depth 65
#
# Epoch = 68, G Energy = -7.58774606 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52081772 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51667236 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51367424 Ha, Sz = -1.00000000
# Number of gates = 68
#
# Circuit depth 66
#
# Epoch = 69, G Energy = -7.57718820 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51816925 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51519309 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51299916 Ha, Sz = -1.00000000
# Number of gates = 69
#
# Circuit depth 67
#
# Epoch = 70, G Energy = -7.40020997 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51449511 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51232943 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51115625 Ha, Sz = -1.00000000
# Number of gates = 70
#
# Circuit depth 68
#
# Epoch = 71, G Energy = -6.67717365 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51853762 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51472558 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.51270779 Ha, Sz = -1.00000000
# Number of gates = 71
#
# Circuit depth 69
#
# Epoch = 72, G Energy = -7.58085958 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51971689 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51313289 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51011463 Ha, Sz = -1.00000000
# Number of gates = 72
#
# Circuit depth 70
#
# Epoch = 73, G Energy = -7.58464056 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51809368 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51253788 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51001513 Ha, Sz = -1.00000000
# Number of gates = 73
#
# Circuit depth 71
#
# Epoch = 74, G Energy = -7.54302356 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51612186 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51115532 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50917968 Ha, Sz = -1.00000000
# Number of gates = 74
#
# Circuit depth 72
#
# Epoch = 75, G Energy = -7.17652510 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51783591 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51230134 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.51006970 Ha, Sz = -1.00000000
# Number of gates = 75
#
# Circuit depth 73
#
# Epoch = 76, G Energy = -6.75599286 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51542816 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50879132 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50686545 Ha, Sz = -1.00000000
# Number of gates = 76
#
# Circuit depth 74
#
# Epoch = 77, G Energy = -7.35581309 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52099777 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50721217 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50468819 Ha, Sz = -1.00000000
# Number of gates = 77
#
# Circuit depth 75
#
# Epoch = 78, G Energy = -7.41548336 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52135830 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50622085 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50378314 Ha, Sz = -1.00000000
# Number of gates = 78
#
# Circuit depth 76
#
# Epoch = 79, G Energy = -7.46628249 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51886102 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50600001 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50380656 Ha, Sz = -1.00000000
# Number of gates = 79
#
# Circuit depth 77
#
# Epoch = 80, G Energy = -7.47461013 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52015264 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50711303 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50445293 Ha, Sz = -1.00000000
# Number of gates = 80
#
# Circuit depth 78
#
# Epoch = 81, G Energy = -7.46989177 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51806604 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50666146 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50428527 Ha, Sz = -1.00000000
# Number of gates = 81
#
# Circuit depth 79
#
# Epoch = 82, G Energy = -7.44331650 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51981268 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50750646 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50470266 Ha, Sz = -1.00000000
# Number of gates = 82
#
# Circuit depth 80
#
# Epoch = 83, G Energy = -7.44150650 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51746134 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50590196 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50355480 Ha, Sz = -1.00000000
# Number of gates = 83
#
# Circuit depth 81
#
# Epoch = 84, G Energy = -7.45118845 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51948336 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50641150 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50365068 Ha, Sz = -1.00000000
# Number of gates = 84
#
# Circuit depth 82
#
# Epoch = 85, G Energy = -7.48489039 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51759312 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50527045 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50276255 Ha, Sz = -1.00000000
# Number of gates = 85
#
# Circuit depth 83
#
# Epoch = 86, G Energy = -7.49602982 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51928923 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50640139 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50338990 Ha, Sz = -1.00000000
# Number of gates = 86
#
# Circuit depth 84
#
# Epoch = 87, G Energy = -7.50135833 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51807984 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50607707 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50312213 Ha, Sz = -1.00000000
# Number of gates = 87
#
# Circuit depth 85
#
# Epoch = 88, G Energy = -7.49069697 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51947889 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50710327 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50373483 Ha, Sz = -1.00000000
# Number of gates = 88
#
# Circuit depth 86
#
# Epoch = 89, G Energy = -7.47854441 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51807696 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50627639 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50308090 Ha, Sz = -1.00000000
# Number of gates = 89
#
# Circuit depth 87
#
# Epoch = 90, G Energy = -7.46123990 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51967277 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50702399 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50341462 Ha, Sz = -1.00000000
# Number of gates = 90
#
# Circuit depth 88
#
# Epoch = 91, G Energy = -7.47555013 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51803354 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50573273 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50232823 Ha, Sz = -1.00000000
# Number of gates = 91
#
# Circuit depth 89
#
# Epoch = 92, G Energy = -7.48712550 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51961597 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50650283 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50266598 Ha, Sz = -1.00000000
# Number of gates = 92
#
# Circuit depth 90
#
# Epoch = 93, G Energy = -7.50335311 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51853577 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50607285 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50227300 Ha, Sz = -1.00000000
# Number of gates = 93
#
# Circuit depth 91
#
# Epoch = 94, G Energy = -7.50490375 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51976709 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50707178 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50287835 Ha, Sz = -1.00000000
# Number of gates = 94
#
# Circuit depth 92
#
# Epoch = 95, G Energy = -7.50329353 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51885898 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50679114 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50265097 Ha, Sz = -1.00000000
# Number of gates = 95
#
# Circuit depth 93
#
# Epoch = 96, G Energy = -7.48906601 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52001114 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50761462 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50311919 Ha, Sz = -1.00000000
# Number of gates = 96
#
# Circuit depth 94
#
# Epoch = 97, G Energy = -7.47970679 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51882850 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50685432 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50246323 Ha, Sz = -1.00000000
# Number of gates = 97
#
# Circuit depth 95
#
# Epoch = 98, G Energy = -7.47132080 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52016456 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50740870 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50263461 Ha, Sz = -1.00000000
# Number of gates = 98
#
# Circuit depth 96
#
# Epoch = 99, G Energy = -7.49119710 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51892161 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50655965 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50183769 Ha, Sz = -1.00000000
# Number of gates = 99
#
# Circuit depth 97
#
# Epoch = 100, G Energy = -7.50019176 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52015954 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50730526 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50223684 Ha, Sz = -1.00000000
# Number of gates = 100
#
# Circuit depth 98
#
# Epoch = 101, G Energy = -7.50896161 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51941016 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50722909 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50213416 Ha, Sz = -1.00000000
# Number of gates = 101
#
# Circuit depth 99
#
# Epoch = 102, G Energy = -7.50596902 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52034779 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50801106 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50264447 Ha, Sz = -1.00000000
# Number of gates = 102
#
# Circuit depth 100
#
# Epoch = 103, G Energy = -7.50037837 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51956043 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50780332 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50244556 Ha, Sz = -1.00000000
# Number of gates = 103
#
# Circuit depth 101
#
# Epoch = 104, G Energy = -7.48370939 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52055850 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50837411 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50274394 Ha, Sz = -1.00000000
# Number of gates = 104
#
# Circuit depth 102
#
# Epoch = 105, G Energy = -7.48109772 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.51948963 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50772504 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50207058 Ha, Sz = -1.00000000
# Number of gates = 105
#
# Circuit depth 103
#
# Epoch = 106, G Energy = -7.48186971 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52062657 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50803217 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50211792 Ha, Sz = -1.00000000
# Number of gates = 106
#
# Circuit depth 104
#
# Epoch = 107, G Energy = -7.50182861 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.51971125 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50768039 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50166790 Ha, Sz = -1.00000000
# Number of gates = 107
#
# Circuit depth 105
#
# Epoch = 108, G Energy = -7.50755560 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52066213 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50831086 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50211025 Ha, Sz = -1.00000000
# Number of gates = 108
#
# Circuit depth 106
#
# Epoch = 109, G Energy = -7.51119235 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52008661 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50845624 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50216770 Ha, Sz = -1.00000000
# Number of gates = 109
#
# Circuit depth 107
#
# Epoch = 110, G Energy = -7.50434065 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52083197 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50899405 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50257503 Ha, Sz = -1.00000000
# Number of gates = 110
#
# Circuit depth 108
#
# Epoch = 111, G Energy = -7.49521066 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52010336 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50886043 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50235131 Ha, Sz = -1.00000000
# Number of gates = 111
#
# Circuit depth 109
#
# Epoch = 112, G Energy = -7.47788733 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52100714 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50909546 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50245637 Ha, Sz = -1.00000000
# Number of gates = 112
#
# Circuit depth 110
#
# Epoch = 113, G Energy = -7.48663423 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52003431 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50859461 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50175979 Ha, Sz = -1.00000000
# Number of gates = 113
#
# Circuit depth 111
#
# Epoch = 114, G Energy = -7.49399272 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52100647 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50874043 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50181580 Ha, Sz = -1.00000000
# Number of gates = 114
#
# Circuit depth 112
#
# Epoch = 115, G Energy = -7.50874574 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52036821 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50887504 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50173072 Ha, Sz = -1.00000000
# Number of gates = 115
#
# Circuit depth 113
#
# Epoch = 116, G Energy = -7.51084803 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52107873 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50933412 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50216462 Ha, Sz = -1.00000000
# Number of gates = 116
#
# Circuit depth 114
#
# Epoch = 117, G Energy = -7.51043579 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52057864 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50958471 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50226353 Ha, Sz = -1.00000000
# Number of gates = 117
#
# Circuit depth 115
#
# Epoch = 118, G Energy = -7.49950031 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52121861 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50985218 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50254863 Ha, Sz = -1.00000000
# Number of gates = 118
#
# Circuit depth 116
#
# Epoch = 119, G Energy = -7.48902519 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52051046 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50976195 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50224483 Ha, Sz = -1.00000000
# Number of gates = 119
#
# Circuit depth 117
#
# Epoch = 120, G Energy = -7.47666264 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52135198 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50960209 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50214387 Ha, Sz = -1.00000000
# Number of gates = 120
#
# Circuit depth 118
#
# Epoch = 121, G Energy = -7.49678691 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52051553 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50938701 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50153844 Ha, Sz = -1.00000000
# Number of gates = 121
#
# Circuit depth 119
#
# Epoch = 122, G Energy = -7.50515143 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52131397 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50955643 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50175636 Ha, Sz = -1.00000000
# Number of gates = 122
#
# Circuit depth 120
#
# Epoch = 123, G Energy = -7.51289883 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52086701 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51000617 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50194234 Ha, Sz = -1.00000000
# Number of gates = 123
#
# Circuit depth 121
#
# Epoch = 124, G Energy = -7.51111523 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52139776 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51026891 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50231641 Ha, Sz = -1.00000000
# Number of gates = 124
#
# Circuit depth 122
#
# Epoch = 125, G Energy = -7.50617643 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52091565 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51053232 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50236812 Ha, Sz = -1.00000000
# Number of gates = 125
#
# Circuit depth 123
#
# Epoch = 126, G Energy = -7.48997503 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52152358 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51046677 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50248627 Ha, Sz = -1.00000000
# Number of gates = 126
#
# Circuit depth 124
#
# Epoch = 127, G Energy = -7.48497207 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52080583 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51035350 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50202394 Ha, Sz = -1.00000000
# Number of gates = 127
#
# Circuit depth 125
#
# Epoch = 128, G Energy = -7.48461431 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52159305 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.50991921 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50178021 Ha, Sz = -1.00000000
# Number of gates = 128
#
# Circuit depth 126
#
# Epoch = 129, G Energy = -7.50664490 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52095675 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51019489 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50150570 Ha, Sz = -1.00000000
# Number of gates = 129
#
# Circuit depth 127
#
# Epoch = 130, G Energy = -7.51304810 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52155100 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51044084 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50205016 Ha, Sz = -1.00000000
# Number of gates = 130
#
# Circuit depth 128
#
# Epoch = 131, G Energy = -7.51617800 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52118719 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51098951 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50239240 Ha, Sz = -1.00000000
# Number of gates = 131
#
# Circuit depth 129
#
# Epoch = 132, G Energy = -7.51156900 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52158086 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51106336 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50279510 Ha, Sz = -1.00000000
# Number of gates = 132
#
# Circuit depth 130
#
# Epoch = 133, G Energy = -7.50205271 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52109471 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51131862 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50278313 Ha, Sz = -1.00000000
# Number of gates = 133
#
# Circuit depth 131
#
# Epoch = 134, G Energy = -7.48117845 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52169227 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51081705 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50282665 Ha, Sz = -1.00000000
# Number of gates = 134
#
# Circuit depth 132
#
# Epoch = 135, G Energy = -7.48755755 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52095605 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51074116 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50215752 Ha, Sz = -1.00000000
# Number of gates = 135
#
# Circuit depth 133
#
# Epoch = 136, G Energy = -7.49633005 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52168891 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51019604 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50206422 Ha, Sz = -1.00000000
# Number of gates = 136
#
# Circuit depth 134
#
# Epoch = 137, G Energy = -7.51316839 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52120463 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51089317 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50215611 Ha, Sz = -1.00000000
# Number of gates = 137
#
# Circuit depth 135
#
# Epoch = 138, G Energy = -7.51715600 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52163673 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51118900 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50265068 Ha, Sz = -1.00000000
# Number of gates = 138
#
# Circuit depth 136
#
# Epoch = 139, G Energy = -7.51803777 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52129782 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51181626 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50293460 Ha, Sz = -1.00000000
# Number of gates = 139
#
# Circuit depth 137
#
# Epoch = 140, G Energy = -7.51107619 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52164419 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51179292 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50320754 Ha, Sz = -1.00000000
# Number of gates = 140
#
# Circuit depth 138
#
# Epoch = 141, G Energy = -7.49786608 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52115591 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51206362 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50309501 Ha, Sz = -1.00000000
# Number of gates = 141
#
# Circuit depth 139
#
# Epoch = 142, G Energy = -7.47595250 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52176730 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51129059 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50291038 Ha, Sz = -1.00000000
# Number of gates = 142
#
# Circuit depth 140
#
# Epoch = 143, G Energy = -7.49655578 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52106477 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51136841 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50212710 Ha, Sz = -1.00000000
# Number of gates = 143
#
# Circuit depth 141
#
# Epoch = 144, G Energy = -7.50780812 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52170565 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51124266 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50219717 Ha, Sz = -1.00000000
# Number of gates = 144
#
# Circuit depth 142
#
# Epoch = 145, G Energy = -7.51802465 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52132948 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51207798 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50254346 Ha, Sz = -1.00000000
# Number of gates = 145
#
# Circuit depth 143
#
# Epoch = 146, G Energy = -7.51949629 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52163028 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51234803 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50293948 Ha, Sz = -1.00000000
# Number of gates = 146
#
# Circuit depth 144
#
# Epoch = 147, G Energy = -7.51761422 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52127032 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51284709 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50315644 Ha, Sz = -1.00000000
# Number of gates = 147
#
# Circuit depth 145
#
# Epoch = 148, G Energy = -7.50515115 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52161230 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51269441 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50329250 Ha, Sz = -1.00000000
# Number of gates = 148
#
# Circuit depth 146
#
# Epoch = 149, G Energy = -7.48993895 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52108100 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51267370 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50301991 Ha, Sz = -1.00000000
# Number of gates = 149
#
# Circuit depth 147
#
# Epoch = 150, G Energy = -7.47870749 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52171404 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51185595 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50255021 Ha, Sz = -1.00000000
# Number of gates = 150
#
# Circuit depth 148
#
# Epoch = 151, G Energy = -7.51142370 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52110109 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51227326 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50197445 Ha, Sz = -1.00000000
# Number of gates = 151
#
# Circuit depth 149
#
# Epoch = 152, G Energy = -7.52087263 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52152804 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51271752 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50257657 Ha, Sz = -1.00000000
# Number of gates = 152
#
# Circuit depth 150
#
# Epoch = 153, G Energy = -7.52526198 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52121424 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51334003 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50310720 Ha, Sz = -1.00000000
# Number of gates = 153
#
# Circuit depth 151
#
# Epoch = 154, G Energy = -7.52369069 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52139365 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51347701 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50350879 Ha, Sz = -1.00000000
# Number of gates = 154
#
# Circuit depth 152
#
# Epoch = 155, G Energy = -7.51527877 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52101233 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51362708 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50365358 Ha, Sz = -1.00000000
# Number of gates = 155
#
# Circuit depth 153
#
# Epoch = 156, G Energy = -7.48788180 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52141675 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51313541 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50368842 Ha, Sz = -1.00000000
# Number of gates = 156
#
# Circuit depth 154
#
# Epoch = 157, G Energy = -7.48101919 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52079920 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51239443 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50296145 Ha, Sz = -1.00000000
# Number of gates = 157
#
# Circuit depth 155
#
# Epoch = 158, G Energy = -7.49500734 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52148771 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51210160 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50236080 Ha, Sz = -1.00000000
# Number of gates = 158
#
# Circuit depth 156
#
# Epoch = 159, G Energy = -7.52326503 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52099035 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51306890 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50254474 Ha, Sz = -1.00000000
# Number of gates = 159
#
# Circuit depth 157
#
# Epoch = 160, G Energy = -7.52966435 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52115975 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51379072 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50326504 Ha, Sz = -1.00000000
# Number of gates = 160
#
# Circuit depth 158
#
# Epoch = 161, G Energy = -7.53245488 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52087129 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51427623 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50375485 Ha, Sz = -1.00000000
# Number of gates = 161
#
# Circuit depth 159
#
# Epoch = 162, G Energy = -7.53022749 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52095806 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51447243 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50409590 Ha, Sz = -1.00000000
# Number of gates = 162
#
# Circuit depth 160
#
# Epoch = 163, G Energy = -7.51490543 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52057780 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51431177 Ha, Sz= -0.00000000
#  The first excited state Energy = -7.50419828 Ha, Sz = -1.00000000
# Number of gates = 163
#
# Circuit depth 161
#
# Epoch = 164, G Energy = -7.46418236 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52102855 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51353470 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50406466 Ha, Sz = -1.00000000
# Number of gates = 164
#
# Circuit depth 162
#
# Epoch = 165, G Energy = -7.47975592 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52038624 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51177087 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50269819 Ha, Sz = -1.00000000
# Number of gates = 165
#
# Circuit depth 163
#
# Epoch = 166, G Energy = -7.50976949 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52107027 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51312131 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50207173 Ha, Sz = -1.00000000
# Number of gates = 166
#
# Circuit depth 164
#
# Epoch = 167, G Energy = -7.53028961 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52065108 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51411232 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50295894 Ha, Sz = -1.00000000
# Number of gates = 167
#
# Circuit depth 165
#
# Epoch = 168, G Energy = -7.53554088 Ha, Sz = 0.00000000 Ha,
#  The first excited state Energy = -7.52069720 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51476870 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50373768 Ha, Sz = -1.00000000
# Number of gates = 168
#
# Circuit depth 166
#
# Epoch = 169, G Energy = -7.53817658 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52040966 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51495793 Ha, Sz= 0.00000000
#  The first excited state Energy = -7.50426202 Ha, Sz = -1.00000000
# Number of gates = 169
#
# Circuit depth 167
#
# Epoch = 170, G Energy = -7.53481261 Ha, Sz = -0.00000000 Ha,
#  The first excited state Energy = -7.52046954 Ha, Sz= 1.00000000
#  The first excited state Energy = -7.51523802 Ha, Sz= 0.00000000
