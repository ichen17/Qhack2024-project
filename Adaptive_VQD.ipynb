# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.34.0-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.11.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.2.1)
# Collecting rustworkx (from pennylane)
#   Downloading rustworkx-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.6.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.4.4)
# Collecting semantic-version>=2.7 (from pennylane)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autoray>=0.6.1 (from pennylane)
#   Downloading autoray-0.6.8-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.3.2)
# Collecting pennylane-lightning>=0.34 (from pennylane)
#   Downloading PennyLane_Lightning-0.34.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.9.0)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2024.2.2)
# Installing collected packages: semantic-version, rustworkx, autoray, pennylane-lightning, pennylane
# Successfully installed autoray-0.6.8 pennylane-0.34.0 pennylane-lightning-0.34.0 rustworkx-0.14.0 semantic-version-2.10.0

# %%
import pennylane as qml
import pennylane.numpy as np
import matplotlib.pyplot as plt

# %%
def hydrogen_hamiltonian(coordinates):
    """Calculates the qubit Hamiltonian of the hydrogen molecule.

    Args:
        coordinates (list(float)): Cartesian coordinates of each hydrogen molecule.
        charge (int): The electric charge given to the hydrogen molecule.

    Returns:
        (qml.Hamiltonian): A PennyLane Hamiltonian.
    """
    return qml.qchem.molecular_hamiltonian(["H", "Li"], coordinates, charge=0, basis="STO-3G",active_electrons=2)[0]


def hf(electrons, num_qubits):
    """Calculates the Hartree-Fock state of the hydrogen molecule.

    Args:
        electrons (int): The number of electrons in the hydrogen molecule.
        num_qubits (int): The number of qubits needed to represent the hydrogen molecule Hamiltonian.

    Returns:
        (numpy.tensor): The HF state.
    """
    # Put your solution here #
    return qml.qchem.hf_state(electrons=electrons, orbitals=num_qubits)

# %%
def num_electrons(charge):
    """The total number of electrons in the hydrogen molecule.

    Args:
        charge (int): The electric charge given to the hydrogen molecule.

    Returns:
        (int): The number of electrons.
    """
    return 2-charge

# %%
def depth(qnode):
    def _fn(*args, **kwargs):
        qnode.construct(args, kwargs)
        return qnode.qtape.get_depth()
    return _fn

# %% [markdown]
# Using exact diagonalization to get the ground state and first excited state.

# %%
L=1.5
coordinates = np.array([0.0, 0.0, -L/2, 0.0, 0.0, L/2]) #np.array([-L/2/np.sqrt(3), L/2, 0.0, L/np.sqrt(3), 0.0, 0.0,-L/2/np.sqrt(3), -L/2, 0.0])
charge=0
hamiltonian = hydrogen_hamiltonian(np.array(coordinates))
H_matrix=qml.matrix(hamiltonian)

# %%
vals, vecs = np.linalg.eigh(H_matrix)

inds=np.argsort(vals)
eng=vals[inds]
vec=vecs[:,inds]

print('The ground state energy:',eng[0])
# Out:
# The ground state energy: -7.626624465547493

# %%
def vec_check(vec,electron_num):
    for i,e in enumerate(vec):
        if np.abs(e) > 1e-8:
            e_occ=bin(i)[2:]
            lst=' '.join(e_occ).split(' ')
            cv=tuple(map(int, lst))
            e_num=sum(cv)
            if e_num!=electron_num:
                return False
    return True

# %%
sz=qml.qchem.spinz(len(hamiltonian.wires))
SZ=qml.matrix(sz)
Stop=[False,False,False]
elec_num=2
for i in range(1,len(eng)): # Finding first excited state with -1 Sz
    Sz=vec[:,i].dot(SZ.dot(np.transpose(np.conjugate(vec[:,i]))))
    #print(Sz)

    if np.abs(Sz) < 1e-5 and vec_check(vec[:,i],elec_num):
        print('The first excied state energy with sz=1:',eng[i])
        Stop[0]=True

    elif np.abs(Sz-1) < 1e-5 and vec_check(vec[:,i],elec_num):
        print('The first excied state energy with sz=0:',eng[i])
        Stop[1]=True

    elif np.abs(Sz+1) < 1e-5 and vec_check(vec[:,i],elec_num):
        print('The first excied state energy with sz=-1:',eng[i])
        Stop[2]=True

    if np.all(Stop):
        break
# Out:
# The first excied state energy with sz=0: -7.522914627103037
# The first excied state energy with sz=1: -7.522914627103034
# The first excied state energy with sz=-1: -7.52291462710303

# %%
electrons = 2
num_qubits = len(hamiltonian.wires)

S2 = qml.qchem.spin2(electrons, num_qubits)
sz=qml.qchem.spinz(num_qubits)

singles, doubles = qml.qchem.excitations(electrons, num_qubits)
pool_operators=singles+doubles

num_qubits = len(hamiltonian.wires)
hf_state = hf(electrons, num_qubits)

dev = qml.device("default.qubit", wires=num_qubits)
print("The original vqe use ",len(doubles)*13 + len(singles)*2," cnot gates")
print("The original vqe use ",len(doubles)*34 + len(singles)*10," gates")

bitstr=''.join(map(str, hf_state))

g_trial_stat={bitstr: 1}
e_trial_stat_szp1={'1010000000': 1}
e_trial_stat_szm1={'0101000000': 1}
e_trial_stat_sz0={'1001000000': 1,'0110000000': 1}

def bit_to_vec(bitstring_dict,num_qubits):
    vec=np.zeros(2**num_qubits)
    amp=0
    for i in range(2**num_qubits):
        bitstr=bin(i)[2:]
        if len(bitstr) < num_qubits:
            bitstr=(num_qubits-len(bitstr))*'0'+bitstr

        if bitstr in bitstring_dict:
            vec[i]=bitstring_dict[bitstr]
            amp+=np.abs(bitstring_dict[bitstr])**2
    vec=vec/np.sqrt(amp)
    return vec

g_stat=bit_to_vec(g_trial_stat,num_qubits)

def circuit(state,weights):
    qml.StatePrep(state, wires=range(num_qubits))
    for i in range(len(singles)):
        qml.SingleExcitation(weights[i+len(doubles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(weights[i], wires=doubles[i])

    return qml.expval(hamiltonian)

def circuit_sz(state,weights):
    qml.StatePrep(state, wires=range(num_qubits))
    for i in range(len(singles)):
        qml.SingleExcitation(weights[i+len(doubles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(weights[i], wires=doubles[i])

    return qml.expval(sz)


cost_h_fn = qml.QNode(circuit, dev)
Sz_fn = qml.QNode(circuit_sz, dev)

def cost_fn(params):
    return cost_h_fn(g_stat,params)

weights =np.zeros(len(doubles + singles), requires_grad=True)

opt = qml.AdamOptimizer(stepsize=0.5)

i=0
iter=[]
cost_val=[]
Lowest_E=0
best_weights=0

cov=1e-6
E0_pev=0


for _ in range(400):
    weights = opt.step(cost_fn, weights)
    iter.append(i)

    E0=cost_h_fn(g_stat,weights)

    if Lowest_E>E0:
        Lowest_E=E0
        best_weights=weights
    cost_val.append(E0)

    i=i+1
    print('Need iter:',i,' E0:',E0,' Sz:',Sz_fn(g_stat,weights))
    #print('E2:',E2,Sz_fn(e_stat_sz0,weights))
    #print('E3:',E3,Sz_fn(e_stat_szm1,weights))
    if np.abs(E0-E0_pev)<cov:# and np.abs(E1-E1_pev)<cov and np.abs(E2-E2_pev)<cov and np.abs(E3-E3_pev)<cov:
        #print('Need iter:',i,' E0:',E0)
        break

    E0_pev=E0
# Out:
# The original vqe use  224  cnot gates
# The original vqe use  624  gates
# Need iter: 1  E0: -7.475187554557702  Sz: 0.0
# Need iter: 2  E0: -7.53914631149875  Sz: -2.7755575615628914e-17
# Need iter: 3  E0: -7.58517297151212  Sz: 2.7755575615628914e-17
# Need iter: 4  E0: -7.53149154544308  Sz: 5.551115123125783e-17
# Need iter: 5  E0: -7.530700124349723  Sz: 0.0
# Need iter: 6  E0: -7.56655319979495  Sz: 2.7755575615628914e-17
# Need iter: 7  E0: -7.590039956292802  Sz: 0.0
# Need iter: 8  E0: -7.58705149685098  Sz: -8.326672684688674e-17
# Need iter: 9  E0: -7.580778730576064  Sz: 0.0
# Need iter: 10  E0: -7.585438382869366  Sz: -2.7755575615628914e-17
# Need iter: 11  E0: -7.599889175920599  Sz: -2.7755575615628914e-17
# Need iter: 12  E0: -7.6126141810066414  Sz: -2.7755575615628914e-17
# Need iter: 13  E0: -7.608241253904193  Sz: 2.7755575615628914e-17
# Need iter: 14  E0: -7.597549385444611  Sz: 2.7755575615628914e-17
# Need iter: 15  E0: -7.5982604705574746  Sz: 0.0
# Need iter: 16  E0: -7.609303957356188  Sz: -2.7755575615628914e-17
# Need iter: 17  E0: -7.616794728396195  Sz: 0.0
# Need iter: 18  E0: -7.613450651425249  Sz: 2.7755575615628914e-17
# Need iter: 19  E0: -7.609210303162769  Sz: -2.7755575615628914e-17
# Need iter: 20  E0: -7.614130368297019  Sz: 0.0
# Need iter: 21  E0: -7.621300236795308  Sz: 0.0
# Need iter: 22  E0: -7.620662742435318  Sz: 0.0
# Need iter: 23  E0: -7.615340475135063  Sz: -2.7755575615628914e-17
# Need iter: 24  E0: -7.6133175939315105  Sz: -2.7755575615628914e-17
# Need iter: 25  E0: -7.617203707427728  Sz: 0.0
# Need iter: 26  E0: -7.623282087870951  Sz: -2.7755575615628914e-17
# Need iter: 27  E0: -7.625085642003951  Sz: 0.0
# Need iter: 28  E0: -7.621385558356816  Sz: 2.7755575615628914e-17
# Need iter: 29  E0: -7.618864984374502  Sz: 2.7755575615628914e-17
# Need iter: 30  E0: -7.621473703938719  Sz: 0.0
# Need iter: 31  E0: -7.62429229589086  Sz: 2.7755575615628914e-17
# Need iter: 32  E0: -7.6234154302016774  Sz: 5.551115123125783e-17
# Need iter: 33  E0: -7.622358966700317  Sz: -5.551115123125783e-17
# Need iter: 34  E0: -7.623822554484248  Sz: 5.551115123125783e-17
# Need iter: 35  E0: -7.62514231563943  Sz: 0.0
# Need iter: 36  E0: -7.624362606441928  Sz: -2.7755575615628914e-17
# Need iter: 37  E0: -7.623443382492431  Sz: -2.7755575615628914e-17
# Need iter: 38  E0: -7.624214260928249  Sz: -5.551115123125783e-17
# Need iter: 39  E0: -7.625437366623427  Sz: -5.551115123125783e-17
# Need iter: 40  E0: -7.625438884843407  Sz: 2.7755575615628914e-17
# Need iter: 41  E0: -7.624895836092993  Sz: 0.0
# Need iter: 42  E0: -7.625041483816408  Sz: -2.7755575615628914e-17
# Need iter: 43  E0: -7.625677719688108  Sz: 0.0
# Need iter: 44  E0: -7.6258079844246875  Sz: -5.551115123125783e-17
# Need iter: 45  E0: -7.625328804468032  Sz: 2.7755575615628914e-17
# Need iter: 46  E0: -7.625316248581773  Sz: 5.551115123125783e-17
# Need iter: 47  E0: -7.626053815249998  Sz: -2.7755575615628914e-17
# Need iter: 48  E0: -7.626418278150638  Sz: -5.551115123125783e-17
# Need iter: 49  E0: -7.625878736080998  Sz: -8.326672684688674e-17
# Need iter: 50  E0: -7.625539825233521  Sz: -2.7755575615628914e-17
# Need iter: 51  E0: -7.626074582592784  Sz: -2.7755575615628914e-17
# Need iter: 52  E0: -7.62644081863421  Sz: 0.0
# Need iter: 53  E0: -7.626138892982933  Sz: 0.0
# Need iter: 54  E0: -7.626063235048788  Sz: -5.551115123125783e-17
# Need iter: 55  E0: -7.6263755447069554  Sz: -2.7755575615628914e-17
# Need iter: 56  E0: -7.626366784887171  Sz: 5.551115123125783e-17
# Need iter: 57  E0: -7.626176313261646  Sz: 0.0
# Need iter: 58  E0: -7.626311356664857  Sz: 0.0
# Need iter: 59  E0: -7.626495464513163  Sz: 2.7755575615628914e-17
# Need iter: 60  E0: -7.626421078879272  Sz: 2.7755575615628914e-17
# Need iter: 61  E0: -7.626342757313358  Sz: -2.7755575615628914e-17
# Need iter: 62  E0: -7.626443927251329  Sz: -5.551115123125783e-17
# Need iter: 63  E0: -7.6265123374241925  Sz: -2.7755575615628914e-17
# Need iter: 64  E0: -7.626446638997207  Sz: -2.7755575615628914e-17
# Need iter: 65  E0: -7.626446035647152  Sz: 0.0

# %%
def circuit_h(state,params):
    Re_w=weights[::-1]
    qml.StatePrep(state, wires=range(num_qubits))

    for i in range(len(singles)):
        qml.SingleExcitation(params[i+len(doubles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(params[i], wires=doubles[i])

    return qml.expval(hamiltonian)

def circuit_fid(state,params,weights):
    Re_w=weights[::-1]
    qml.StatePrep(state, wires=range(num_qubits))

    for i in range(len(singles)):
        qml.SingleExcitation(params[i+len(doubles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(params[i], wires=doubles[i])

    for i in range(len(singles)):
        qml.SingleExcitation(params[i+2*len(doubles)+len(singles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(params[i+len(doubles)+len(singles)], wires=doubles[i])

    for i, double in enumerate(doubles[::-1]):
        qml.DoubleExcitation(-Re_w[i], wires=double)
    for i, single in enumerate(singles[::-1]):
        qml.SingleExcitation(-Re_w[i+len(doubles)], wires=single)
    qml.PauliX(wires=0)
    qml.PauliX(wires=1)
    return qml.probs(wires=range(len(hamiltonian.wires)))

cost_h_fn = qml.QNode(circuit_h, dev)
cost_fid_fn = qml.QNode(circuit_fid, dev)
Sz_fn = qml.QNode(circuit_sz, dev)

params =np.zeros(2*len(doubles + singles), requires_grad=True)

e_trial_stat_sz0={'1001000000': 1,'0110000000': 1}
e_stat_sz0=bit_to_vec(e_trial_stat_sz0,num_qubits)

def cost_fn(params):
    return cost_h_fn(e_stat_sz0,params)+15*cost_fid_fn(e_stat_sz0,params,weights)[0]

opt = qml.AdamOptimizer(stepsize=0.5)


i=0
iter=[]
cost_val=[]
Lowest_E=0
best_weights=0

cov=1e-6
E0_pev=0


for _ in range(400):
    params = opt.step(cost_fn, params)
    iter.append(i)

    E0=cost_h_fn(e_stat_sz0,params)

    if Lowest_E>E0:
        Lowest_E=E0
        best_weights=params
    cost_val.append(E0)

    i=i+1
    print('Need iter:',i,' E0:',E0,' Sz:',Sz_fn(e_stat_sz0,params))
    print("Cost function",cost_fn(params))
    if np.abs(E0-E0_pev)<cov:
        break

    E0_pev=E0
# Out:
# Need iter: 1  E0: -7.446411263203471  Sz: 2.7755575615628914e-17
# Cost function -5.171680512891753
# Need iter: 2  E0: -7.40071658984707  Sz: -2.7755575615628914e-17
# Cost function -5.298275338882043
# Need iter: 3  E0: -7.343465235692263  Sz: 2.7755575615628914e-17
# Cost function -6.255002070256606
# Need iter: 4  E0: -7.323560801319906  Sz: 0.0
# Cost function -6.477458016326187
# Need iter: 5  E0: -7.31725385555546  Sz: 2.7755575615628914e-17
# Cost function -7.297893965866355
# Need iter: 6  E0: -7.2879452812352765  Sz: 2.7755575615628914e-17
# Cost function -7.28092698544606
# Need iter: 7  E0: -7.250666217760328  Sz: -8.326672684688674e-17
# Cost function -7.249275869139003
# Need iter: 8  E0: -7.218975996818737  Sz: -5.551115123125783e-17
# Cost function -7.188041857575877
# Need iter: 9  E0: -7.199493088784189  Sz: 1.1102230246251565e-16
# Cost function -7.18266910787519
# Need iter: 10  E0: -7.190443342347623  Sz: -5.551115123125783e-17
# Cost function -7.19037514351291
# Need iter: 11  E0: -7.1898900089352304  Sz: 0.0
# Cost function -7.184196675239045
# Need iter: 12  E0: -7.197727510574005  Sz: 8.326672684688674e-17
# Cost function -7.19651970131021
# Need iter: 13  E0: -7.213660999431203  Sz: 2.7755575615628914e-17
# Cost function -7.2105472156397346
# Need iter: 14  E0: -7.236805597649953  Sz: -2.7755575615628914e-17
# Cost function -7.220097127105502
# Need iter: 15  E0: -7.266145984833801  Sz: -2.7755575615628914e-17
# Cost function -7.245152849547693
# Need iter: 16  E0: -7.300599117849009  Sz: 0.0
# Cost function -7.2897228970993915
# Need iter: 17  E0: -7.338376696225474  Sz: 2.7755575615628914e-17
# Cost function -7.336691623350761
# Need iter: 18  E0: -7.376760913528648  Sz: -5.551115123125783e-17
# Cost function -7.376673159039178
# Need iter: 19  E0: -7.412390148896651  Sz: -5.551115123125783e-17
# Cost function -7.411399329601475
# Need iter: 20  E0: -7.441706122764999  Sz: 0.0
# Cost function -7.440851993810567
# Need iter: 21  E0: -7.461857051976565  Sz: 2.7755575615628914e-17
# Cost function -7.461641649319974
# Need iter: 22  E0: -7.471954539147412  Sz: -5.551115123125783e-17
# Cost function -7.4719534027487455
# Need iter: 23  E0: -7.4736845006501245  Sz: 5.551115123125783e-17
# Cost function -7.473558001879791
# Need iter: 24  E0: -7.470584637315609  Sz: -2.7755575615628914e-17
# Cost function -7.470416825661155
# Need iter: 25  E0: -7.466513715933425  Sz: 2.7755575615628914e-17
# Cost function -7.46648146684888
# Need iter: 26  E0: -7.464364686405072  Sz: 0.0
# Cost function -7.464272900304259
# Need iter: 27  E0: -7.465530822183265  Sz: 5.551115123125783e-17
# Cost function -7.4645848786409825
# Need iter: 28  E0: -7.469997015114551  Sz: 0.0
# Cost function -7.466951060149918
# Need iter: 29  E0: -7.476764736249228  Sz: -2.7755575615628914e-17
# Cost function -7.470321449715495
# Need iter: 30  E0: -7.48440634710197  Sz: -8.326672684688674e-17
# Cost function -7.473623114479313
# Need iter: 31  E0: -7.491609582067337  Sz: -1.1102230246251565e-16
# Cost function -7.476225448102358
# Need iter: 32  E0: -7.497575301835712  Sz: 2.7755575615628914e-17
# Cost function -7.478331685789826
# Need iter: 33  E0: -7.502144273706165  Sz: 2.7755575615628914e-17
# Cost function -7.480991447449722
# Need iter: 34  E0: -7.5056238888346005  Sz: 0.0
# Cost function -7.485423094421768
# Need iter: 35  E0: -7.508446078987125  Sz: -2.7755575615628914e-17
# Cost function -7.491999077815951
# Need iter: 36  E0: -7.51087955751229  Sz: -5.551115123125783e-17
# Cost function -7.499794222945684
# Need iter: 37  E0: -7.512943198480252  Sz: 2.7755575615628914e-17
# Cost function -7.50711185475869
# Need iter: 38  E0: -7.514503555252462  Sz: -8.326672684688674e-17
# Cost function -7.512459949283877
# Need iter: 39  E0: -7.515435927994013  Sz: 2.7755575615628914e-17
# Cost function -7.515204732026792
# Need iter: 40  E0: -7.515734653250238  Sz: -5.551115123125783e-17
# Cost function -7.515609563766346
# Need iter: 41  E0: -7.515529670093902  Sz: 2.7755575615628914e-17
# Cost function -7.514466637295126
# Need iter: 42  E0: -7.515034809643921  Sz: -2.7755575615628914e-17
# Cost function -7.512668545779185
# Need iter: 43  E0: -7.514477736197805  Sz: -5.551115123125783e-17
# Cost function -7.510932081621565
# Need iter: 44  E0: -7.514046741365  Sz: 2.7755575615628914e-17
# Cost function -7.509704201802125
# Need iter: 45  E0: -7.5138641759119364  Sz: -2.7755575615628914e-17
# Cost function -7.50918398553146
# Need iter: 46  E0: -7.513980521737936  Sz: -5.551115123125783e-17
# Cost function -7.509386930835521
# Need iter: 47  E0: -7.514380016444429  Sz: -2.7755575615628914e-17
# Cost function -7.510207797603354
# Need iter: 48  E0: -7.514992509717672  Sz: 2.7755575615628914e-17
# Cost function -7.511467916709209
# Need iter: 49  E0: -7.5157105342719035  Sz: -8.326672684688674e-17
# Cost function -7.512950203077214
# Need iter: 50  E0: -7.516411904234586  Sz: 8.326672684688674e-17
# Cost function -7.514430390154934
# Need iter: 51  E0: -7.516986158822468  Sz: -2.7755575615628914e-17
# Cost function -7.5157100068276055
# Need iter: 52  E0: -7.517359784948678  Sz: -2.7755575615628914e-17
# Cost function -7.516649743403301
# Need iter: 53  E0: -7.517513058332325  Sz: -8.326672684688674e-17
# Cost function -7.517195379019756
# Need iter: 54  E0: -7.517482366547139  Sz: -8.326672684688674e-17
# Cost function -7.517385806815295
# Need iter: 55  E0: -7.51734612118451  Sz: -5.551115123125783e-17
# Cost function -7.517335875164635
# Need iter: 56  E0: -7.517198300054989  Sz: 2.7755575615628914e-17
# Cost function -7.517195679759019
# Need iter: 57  E0: -7.517118789970486  Sz: 0.0
# Cost function -7.517099445876446
# Need iter: 58  E0: -7.51715145507145  Sz: -1.3877787807814457e-16
# Cost function -7.517124735488845
# Need iter: 59  E0: -7.5172977493966355  Sz: 5.551115123125783e-17
# Cost function -7.51727969317737
# Need iter: 60  E0: -7.517526558632945  Sz: 8.326672684688674e-17
# Cost function -7.51752168939617
# Need iter: 61  E0: -7.517793257459549  Sz: -2.7755575615628914e-17
# Cost function -7.517793204940862
# Need iter: 62  E0: -7.51805725558666  Sz: 5.551115123125783e-17
# Cost function -7.518051987170952
# Need iter: 63  E0: -7.5182902109674625  Sz: 0.0
# Cost function -7.518279026381805
# Need iter: 64  E0: -7.518474792007076  Sz: 0.0
# Cost function -7.5184658923718555
# Need iter: 65  E0: -7.518600558178532  Sz: 0.0
# Cost function -7.518599201371328
# Need iter: 66  E0: -7.518663768638421  Sz: -2.7755575615628914e-17
# Cost function -7.518660533486034
# Need iter: 67  E0: -7.518671785427026  Sz: -5.551115123125783e-17
# Cost function -7.518643618185052
# Need iter: 68  E0: -7.518646171148043  Sz: 0.0
# Cost function -7.518571987608024
# Need iter: 69  E0: -7.518617992969969  Sz: 2.7755575615628914e-17
# Cost function -7.518497079280543
# Need iter: 70  E0: -7.5186151373794985  Sz: -8.326672684688674e-17
# Cost function -7.518472548330679
# Need iter: 71  E0: -7.518649140476033  Sz: 8.326672684688674e-17
# Cost function -7.518522183143601
# Need iter: 72  E0: -7.518710986253821  Sz: 0.0
# Cost function -7.518626800694112
# Need iter: 73  E0: -7.518779147230425  Sz: -2.7755575615628914e-17
# Cost function -7.518740861172653
# Need iter: 74  E0: -7.518833898519284  Sz: -2.7755575615628914e-17
# Cost function -7.518824824867371
# Need iter: 75  E0: -7.518867683202594  Sz: 0.0
# Cost function -7.518867551407623
# Need iter: 76  E0: -7.518885468592642  Sz: 0.0
# Cost function -7.518883997662785
# Need iter: 77  E0: -7.518897414813931  Sz: 8.326672684688674e-17
# Cost function -7.5188952782894
# Need iter: 78  E0: -7.518911295657216  Sz: 5.551115123125783e-17
# Cost function -7.5189110697148545
# Need iter: 79  E0: -7.51893014735954  Sz: -5.551115123125783e-17
# Cost function -7.518928333836871
# Need iter: 80  E0: -7.518954502557851  Sz: -8.326672684688674e-17
# Cost function -7.518942849007739
# Need iter: 81  E0: -7.518984614740806  Sz: 0.0
# Cost function -7.518958529374705
# Need iter: 82  E0: -7.519019668834611  Sz: 5.551115123125783e-17
# Cost function -7.518984309090441
# Need iter: 83  E0: -7.5190555633871465  Sz: 2.7755575615628914e-17
# Cost function -7.51902297002805
# Need iter: 84  E0: -7.5190851047386715  Sz: -8.326672684688674e-17
# Cost function -7.519065048241035
# Need iter: 85  E0: -7.5191019446009735  Sz: 0.0
# Cost function -7.519095188572401
# Need iter: 86  E0: -7.519105193927744  Sz: 2.7755575615628914e-17
# Cost function -7.519104877748304
# Need iter: 87  E0: -7.519100290289491  Sz: -2.7755575615628914e-17
# Cost function -7.519098980834304
# Need iter: 88  E0: -7.519095007824812  Sz: -8.326672684688674e-17
# Cost function -7.519090287172713
# Need iter: 89  E0: -7.519094085124045  Sz: 5.551115123125783e-17
# Cost function -7.519088313905833

# %%
electrons = 2
num_qubits = len(hamiltonian.wires)

singles, doubles = qml.qchem.excitations(electrons, num_qubits)
pool_operators=singles+doubles

num_qubits = len(hamiltonian.wires)
hf_state = hf(electrons, num_qubits)

def circuit_1(state,weights,excitations):
    qml.StatePrep(state, wires=range(num_qubits))
    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(weights[i], wires=excitation)
        else:
            qml.SingleExcitation(weights[i], wires=excitation)
    return qml.expval(hamiltonian)

def circuit_sz(state,weights,excitations):
    qml.StatePrep(state, wires=range(num_qubits))
    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(weights[i], wires=excitation)
        else:
            qml.SingleExcitation(weights[i], wires=excitation)
    return qml.expval(sz)

dev = qml.device("default.qubit", wires=num_qubits)#

cost_h_fn = qml.QNode(circuit_1, dev, expansion_strategy="device")
Sz_fn = qml.QNode(circuit_sz, dev)

def cost_fn(params, excitations):
    return cost_h_fn(g_stat,params, excitations)


epochs=50

energy=[]
operator_circuits=[]# doubles_select+singles_select

weights = [] #[0.0] * len(operator_circuits)
weights=np.array(weights)

opt = opt = qml.GradientDescentOptimizer(stepsize=0.25)

circuit_gradient = qml.grad(cost_fn, argnum=0)


E0 = cost_h_fn(g_stat,weights, operator_circuits)

print(f"Epoch = 0, G Energy = {E0:.8f} Ha")

print("Number of gates = {}\n".format(len(operator_circuits)))

configs=qml.specs(cost_h_fn)(g_stat,weights, excitations=operator_circuits)

#print(configs)
print("Circuit depth {}\n".format(configs['resources'].depth))

conv=1e-7
E0_pev=0
E1_pev=0
E2_pev=0
E3_pev=0
for n in range(epochs):

    Test_set=operator_circuits+pool_operators
    Test_params=list(weights)+[0.0]*len(pool_operators)
    Test_params=np.array(Test_params)

    test_grads = circuit_gradient(Test_params,Test_set)
    test_grads = test_grads[len(weights):]
    maxpos = np.argmax(np.abs(test_grads))

    max_op=pool_operators[maxpos]
    operator_circuits.append(max_op)
    weights=np.append(weights, 0.0)

    weights,_ = opt.step(cost_fn, weights, operator_circuits) # Step 11.
    E0 = cost_h_fn(g_stat,weights,operator_circuits)


    print(f"Epoch = {n+1}, G Energy = {E0:.8f} Ha, Sz = {Sz_fn(g_stat,weights,operator_circuits):.8f} Ha,")
    print("Number of gates = {}\n".format(len(operator_circuits)))
    configs=qml.specs(cost_h_fn)(g_stat,weights, excitations=operator_circuits)
    print("Circuit depth {}\n".format(configs['resources'].depth))

    if np.abs(E0-E0_pev)<cov:
        break

    E0_pev=E0
# Out:
# Epoch = 0, G Energy = -7.60898166 Ha
# Number of gates = 0
#
# Circuit depth 1
#
# Epoch = 1, G Energy = -7.61248262 Ha, Sz = 0.00000000 Ha,
# Number of gates = 1
#
# Circuit depth 2
#
# Epoch = 2, G Energy = -7.61715784 Ha, Sz = 0.00000000 Ha,
# Number of gates = 2
#
# Circuit depth 3
#
# Epoch = 3, G Energy = -7.62030985 Ha, Sz = 0.00000000 Ha,
# Number of gates = 3
#
# Circuit depth 4
#
# Epoch = 4, G Energy = -7.62145953 Ha, Sz = 0.00000000 Ha,
# Number of gates = 4
#
# Circuit depth 5
#
# Epoch = 5, G Energy = -7.62183402 Ha, Sz = 0.00000000 Ha,
# Number of gates = 5
#
# Circuit depth 6
#
# Epoch = 6, G Energy = -7.62221333 Ha, Sz = 0.00000000 Ha,
# Number of gates = 6
#
# Circuit depth 7
#
# Epoch = 7, G Energy = -7.62268682 Ha, Sz = 0.00000000 Ha,
# Number of gates = 7
#
# Circuit depth 8
#
# Epoch = 8, G Energy = -7.62325700 Ha, Sz = 0.00000000 Ha,
# Number of gates = 8
#
# Circuit depth 9
#
# Epoch = 9, G Energy = -7.62387571 Ha, Sz = 0.00000000 Ha,
# Number of gates = 9
#
# Circuit depth 10
#
# Epoch = 10, G Energy = -7.62446129 Ha, Sz = 0.00000000 Ha,
# Number of gates = 10
#
# Circuit depth 11
#
# Epoch = 11, G Energy = -7.62496630 Ha, Sz = 0.00000000 Ha,
# Number of gates = 11
#
# Circuit depth 12
#
# Epoch = 12, G Energy = -7.62536293 Ha, Sz = 0.00000000 Ha,
# Number of gates = 12
#
# Circuit depth 13
#
# Epoch = 13, G Energy = -7.62565892 Ha, Sz = 0.00000000 Ha,
# Number of gates = 13
#
# Circuit depth 14
#
# Epoch = 14, G Energy = -7.62587067 Ha, Sz = 0.00000000 Ha,
# Number of gates = 14
#
# Circuit depth 15
#
# Epoch = 15, G Energy = -7.62601463 Ha, Sz = 0.00000000 Ha,
# Number of gates = 15
#
# Circuit depth 16
#
# Epoch = 16, G Energy = -7.62611445 Ha, Sz = 0.00000000 Ha,
# Number of gates = 16
#
# Circuit depth 17
#
# Epoch = 17, G Energy = -7.62619297 Ha, Sz = -0.00000000 Ha,
# Number of gates = 17
#
# Circuit depth 18
#
# Epoch = 18, G Energy = -7.62625497 Ha, Sz = 0.00000000 Ha,
# Number of gates = 18
#
# Circuit depth 19
#
# Epoch = 19, G Energy = -7.62629948 Ha, Sz = -0.00000000 Ha,
# Number of gates = 19
#
# Circuit depth 20
#
# Epoch = 20, G Energy = -7.62632745 Ha, Sz = 0.00000000 Ha,
# Number of gates = 20
#
# Circuit depth 21
#
# Epoch = 21, G Energy = -7.62634503 Ha, Sz = 0.00000000 Ha,
# Number of gates = 21
#
# Circuit depth 22
#
# Epoch = 22, G Energy = -7.62635941 Ha, Sz = -0.00000000 Ha,
# Number of gates = 22
#
# Circuit depth 23
#
# Epoch = 23, G Energy = -7.62637345 Ha, Sz = 0.00000000 Ha,
# Number of gates = 23
#
# Circuit depth 24
#
# Epoch = 24, G Energy = -7.62638843 Ha, Sz = 0.00000000 Ha,
# Number of gates = 24
#
# Circuit depth 24
#
# Epoch = 25, G Energy = -7.62640507 Ha, Sz = 0.00000000 Ha,
# Number of gates = 25
#
# Circuit depth 24
#
# Epoch = 26, G Energy = -7.62642332 Ha, Sz = 0.00000000 Ha,
# Number of gates = 26
#
# Circuit depth 24
#
# Epoch = 27, G Energy = -7.62644270 Ha, Sz = -0.00000000 Ha,
# Number of gates = 27
#
# Circuit depth 25
#
# Epoch = 28, G Energy = -7.62646249 Ha, Sz = 0.00000000 Ha,
# Number of gates = 28
#
# Circuit depth 26
#
# Epoch = 29, G Energy = -7.62648192 Ha, Sz = -0.00000000 Ha,
# Number of gates = 29
#
# Circuit depth 27
#
# Epoch = 30, G Energy = -7.62650040 Ha, Sz = 0.00000000 Ha,
# Number of gates = 30
#
# Circuit depth 27
#
# Epoch = 31, G Energy = -7.62651782 Ha, Sz = 0.00000000 Ha,
# Number of gates = 31
#
# Circuit depth 27
#
# Epoch = 32, G Energy = -7.62653393 Ha, Sz = -0.00000000 Ha,
# Number of gates = 32
#
# Circuit depth 27
#
# Epoch = 33, G Energy = -7.62654852 Ha, Sz = -0.00000000 Ha,
# Number of gates = 33
#
# Circuit depth 28
#
# Epoch = 34, G Energy = -7.62656143 Ha, Sz = 0.00000000 Ha,
# Number of gates = 34
#
# Circuit depth 29
#
# Epoch = 35, G Energy = -7.62657263 Ha, Sz = -0.00000000 Ha,
# Number of gates = 35
#
# Circuit depth 29
#
# Epoch = 36, G Energy = -7.62658222 Ha, Sz = 0.00000000 Ha,
# Number of gates = 36
#
# Circuit depth 29
#
# Epoch = 37, G Energy = -7.62659030 Ha, Sz = 0.00000000 Ha,
# Number of gates = 37
#
# Circuit depth 30
#
# Epoch = 38, G Energy = -7.62659702 Ha, Sz = 0.00000000 Ha,
# Number of gates = 38
#
# Circuit depth 30
#
# Epoch = 39, G Energy = -7.62660256 Ha, Sz = -0.00000000 Ha,
# Number of gates = 39
#
# Circuit depth 31
#
# Epoch = 40, G Energy = -7.62660706 Ha, Sz = 0.00000000 Ha,
# Number of gates = 40
#
# Circuit depth 32
#
# Epoch = 41, G Energy = -7.62661067 Ha, Sz = 0.00000000 Ha,
# Number of gates = 41
#
# Circuit depth 33
#
# Epoch = 42, G Energy = -7.62661354 Ha, Sz = 0.00000000 Ha,
# Number of gates = 42
#
# Circuit depth 34
#
# Epoch = 43, G Energy = -7.62661579 Ha, Sz = -0.00000000 Ha,
# Number of gates = 43
#
# Circuit depth 35
#
# Epoch = 44, G Energy = -7.62661758 Ha, Sz = -0.00000000 Ha,
# Number of gates = 44
#
# Circuit depth 35
#
# Epoch = 45, G Energy = -7.62661903 Ha, Sz = -0.00000000 Ha,
# Number of gates = 45
#
# Circuit depth 35
#
# Epoch = 46, G Energy = -7.62662021 Ha, Sz = -0.00000000 Ha,
# Number of gates = 46
#
# Circuit depth 35
#
# Epoch = 47, G Energy = -7.62662117 Ha, Sz = 0.00000000 Ha,
# Number of gates = 47
#
# Circuit depth 36

# %% [markdown]
# For $S_z=0$,

# %%
e_trial_stat_sz0={'1001000000': 1,'0110000000': 1}
e_stat_sz0=bit_to_vec(e_trial_stat_sz0,num_qubits)

def circuit_h(state,params,excitations):
    qml.StatePrep(state, wires=range(num_qubits))
    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(params[i], wires=excitation)
        else:
            qml.SingleExcitation(params[i], wires=excitation)

    return qml.expval(hamiltonian)


def circuit_fid(state,params,excitations):
    qml.StatePrep(state, wires=range(num_qubits))
    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(params[i], wires=excitation)
        else:
            qml.SingleExcitation(params[i], wires=excitation)

    Re_w=weights[::-1]
    for i, excitation in enumerate(operator_circuits[::-1]):
        if len(excitation) == 4:
            qml.DoubleExcitation(-Re_w[i], wires=excitation)
        else:
            qml.SingleExcitation(-Re_w[i], wires=excitation)
    qml.PauliX(wires=0)
    qml.PauliX(wires=1)
    return qml.probs(wires=range(num_qubits))

cost_h_fn = qml.QNode(circuit_h, dev, expansion_strategy="device")
fid_fn = qml.QNode(circuit_fid, dev)

def cost_fn(params, excitations):
    return cost_h_fn(e_stat_sz0,params, excitations)+10*fid_fn(e_stat_sz0,params, excitations)[0]

epochs=150

params = [0.0] * len(doubles)
params=np.array(params )

dev = qml.device("default.qubit", wires=num_qubits)

circuit_gradient = qml.grad(cost_fn, argnum=0)
grads_d = circuit_gradient(params, excitations=doubles)

params = [0.0] * len(singles)
params=np.array(params )

#dev = qml.device("default.qubit", wires=num_qubits)

#circuit_gradient = qml.grad(cost_fn, argnum=0)
grads_s = circuit_gradient(params, excitations=singles)

threshold=1e-5
doubles_select = [(doubles)[i] for i in range(len(doubles)) if abs(grads_d[i]) > threshold]
singles_select = [(singles)[i] for i in range(len(singles)) if abs(grads_s[i]) > threshold]

energy=[]
op_cir=doubles_select+singles_select
params = [0.0] * len(op_cir)
params=np.array(params )

opt = opt = qml.GradientDescentOptimizer(stepsize=0.03)

circuit_gradient = qml.grad(cost_fn, argnum=0)

E2 = cost_h_fn(e_stat_sz0,params, op_cir)


print(f"Epoch = 0, G Energy = {E2:.8f} Ha,")

print("Number of gates = {}\n".format(len(op_cir)))

configs=qml.specs(cost_h_fn)(g_stat,params, excitations=op_cir)

#print(configs)
print("Circuit depth {}\n".format(configs['resources'].depth))

conv=1e-7

E2_pev=0

for n in range(epochs):

    Test_set=op_cir+pool_operators
    Test_params=list(params)+[0.0]*len(pool_operators)
    Test_params=np.array(Test_params)

    test_grads = circuit_gradient(Test_params,Test_set)
    test_grads = test_grads[len(params):]
    maxpos = np.argmax(np.abs(test_grads))

    max_op=pool_operators[maxpos]
    op_cir.append(max_op)
    params=np.append(params, 0.0)

    params,_ = opt.step(cost_fn, params, op_cir) # Step 11.
    print('Cost function',cost_fn(params, op_cir))
    E2 = cost_h_fn(e_stat_sz0,params, op_cir)


    print(f"Epoch = {n+1}")
    print(f" The first excited state Energy = {E2:.8f} Ha, Sz= {Sz_fn(e_stat_sz0,params,op_cir):.8f}")
    print("Number of gates = {}\n".format(len(op_cir)))
    configs=qml.specs(cost_h_fn)(e_stat_sz0, params, excitations=op_cir)
    print("Circuit depth {}\n".format(configs['resources'].depth))

    if np.abs(E2-E2_pev)<cov:
        break
    E2_pev=E2
# Out:
# Epoch = 0, G Energy = -7.49074895 Ha,
# Number of gates = 4
#
# Circuit depth 3
#
# Cost function -7.491147395175579
# Epoch = 1
#  The first excited state Energy = -7.49114747 Ha, Sz= 0.00000000
# Number of gates = 5
#
# Circuit depth 4
#
# Cost function -7.491671097183963
# Epoch = 2
#  The first excited state Energy = -7.49167115 Ha, Sz= 0.00000000
# Number of gates = 6
#
# Circuit depth 4
#
# Cost function -7.492313534316348
# Epoch = 3
#  The first excited state Energy = -7.49231360 Ha, Sz= -0.00000000
# Number of gates = 7
#
# Circuit depth 5
#
# Cost function -7.493065708213647
# Epoch = 4
#  The first excited state Energy = -7.49306575 Ha, Sz= 0.00000000
# Number of gates = 8
#
# Circuit depth 5
#
# Cost function -7.493918336520827
# Epoch = 5
#  The first excited state Energy = -7.49391834 Ha, Sz= 0.00000000
# Number of gates = 9
#
# Circuit depth 6
#
# Cost function -7.494860805664062
# Epoch = 6
#  The first excited state Energy = -7.49486081 Ha, Sz= 0.00000000
# Number of gates = 10
#
# Circuit depth 6
#
# Cost function -7.495881739885801
# Epoch = 7
#  The first excited state Energy = -7.49588174 Ha, Sz= 0.00000000
# Number of gates = 11
#
# Circuit depth 7
#
# Cost function -7.49696792845745
# Epoch = 8
#  The first excited state Energy = -7.49696793 Ha, Sz= 0.00000000
# Number of gates = 12
#
# Circuit depth 7
#
# Cost function -7.498106750948508
# Epoch = 9
#  The first excited state Energy = -7.49810678 Ha, Sz= -0.00000000
# Number of gates = 13
#
# Circuit depth 8
#
# Cost function -7.49928529086085
# Epoch = 10
#  The first excited state Energy = -7.49928534 Ha, Sz= 0.00000000
# Number of gates = 14
#
# Circuit depth 8
#
# Cost function -7.500490706704537
# Epoch = 11
#  The first excited state Energy = -7.50049076 Ha, Sz= 0.00000000
# Number of gates = 15
#
# Circuit depth 9
#
# Cost function -7.501708945836538
# Epoch = 12
#  The first excited state Energy = -7.50170897 Ha, Sz= 0.00000000
# Number of gates = 16
#
# Circuit depth 10
#
# Cost function -7.502928030576455
# Epoch = 13
#  The first excited state Energy = -7.50292807 Ha, Sz= 0.00000000
# Number of gates = 17
#
# Circuit depth 10
#
# Cost function -7.504137795724961
# Epoch = 14
#  The first excited state Energy = -7.50413789 Ha, Sz= 0.00000000
# Number of gates = 18
#
# Circuit depth 10
#
# Cost function -7.505327370466637
# Epoch = 15
#  The first excited state Energy = -7.50532761 Ha, Sz= 0.00000000
# Number of gates = 19
#
# Circuit depth 11
#
# Cost function -7.506485820382597
# Epoch = 16
#  The first excited state Energy = -7.50648634 Ha, Sz= 0.00000000
# Number of gates = 20
#
# Circuit depth 12
#
# Cost function -7.507603599244482
# Epoch = 17
#  The first excited state Energy = -7.50760435 Ha, Sz= -0.00000000
# Number of gates = 21
#
# Circuit depth 12
#
# Cost function -7.508674706607397
# Epoch = 18
#  The first excited state Energy = -7.50867560 Ha, Sz= -0.00000000
# Number of gates = 22
#
# Circuit depth 12
#
# Cost function -7.509693186676865
# Epoch = 19
#  The first excited state Energy = -7.50969414 Ha, Sz= 0.00000000
# Number of gates = 23
#
# Circuit depth 13
#
# Cost function -7.510653601646056
# Epoch = 20
#  The first excited state Energy = -7.51065454 Ha, Sz= 0.00000000
# Number of gates = 24
#
# Circuit depth 14
#
# Cost function -7.511552512532813
# Epoch = 21
#  The first excited state Energy = -7.51155359 Ha, Sz= 0.00000000
# Number of gates = 25
#
# Circuit depth 14
#
# Cost function -7.512388426714087
# Epoch = 22
#  The first excited state Energy = -7.51238976 Ha, Sz= 0.00000000
# Number of gates = 26
#
# Circuit depth 14
#
# Cost function -7.513160161865215
# Epoch = 23
#  The first excited state Energy = -7.51316189 Ha, Sz= 0.00000000
# Number of gates = 27
#
# Circuit depth 15
#
# Cost function -7.513867131112423
# Epoch = 24
#  The first excited state Energy = -7.51386937 Ha, Sz= 0.00000000
# Number of gates = 28
#
# Circuit depth 16
#
# Cost function -7.51451001434105
# Epoch = 25
#  The first excited state Energy = -7.51451265 Ha, Sz= 0.00000000
# Number of gates = 29
#
# Circuit depth 16
#
# Cost function -7.515091122811591
# Epoch = 26
#  The first excited state Energy = -7.51509403 Ha, Sz= -0.00000000
# Number of gates = 30
#
# Circuit depth 16
#
# Cost function -7.515612883118227
# Epoch = 27
#  The first excited state Energy = -7.51561597 Ha, Sz= 0.00000000
# Number of gates = 31
#
# Circuit depth 17
#
# Cost function -7.516077987240551
# Epoch = 28
#  The first excited state Energy = -7.51608118 Ha, Sz= 0.00000000
# Number of gates = 32
#
# Circuit depth 18
#
# Cost function -7.51648976757622
# Epoch = 29
#  The first excited state Energy = -7.51649322 Ha, Sz= 0.00000000
# Number of gates = 33
#
# Circuit depth 18
#
# Cost function -7.516852198064013
# Epoch = 30
#  The first excited state Energy = -7.51685603 Ha, Sz= 0.00000000
# Number of gates = 34
#
# Circuit depth 18
#
# Cost function -7.5171691196538974
# Epoch = 31
#  The first excited state Energy = -7.51717342 Ha, Sz= -0.00000000
# Number of gates = 35
#
# Circuit depth 19
#
# Cost function -7.5174443189503135
# Epoch = 32
#  The first excited state Energy = -7.51744915 Ha, Sz= 0.00000000
# Number of gates = 36
#
# Circuit depth 20
#
# Cost function -7.517681742775279
# Epoch = 33
#  The first excited state Energy = -7.51768699 Ha, Sz= 0.00000000
# Number of gates = 37
#
# Circuit depth 20
#
# Cost function -7.517885421110965
# Epoch = 34
#  The first excited state Energy = -7.51789098 Ha, Sz= -0.00000000
# Number of gates = 38
#
# Circuit depth 20
#
# Cost function -7.5180590594073795
# Epoch = 35
#  The first excited state Energy = -7.51806485 Ha, Sz= 0.00000000
# Number of gates = 39
#
# Circuit depth 21
#
# Cost function -7.518206099140113
# Epoch = 36
#  The first excited state Energy = -7.51821207 Ha, Sz= 0.00000000
# Number of gates = 40
#
# Circuit depth 22
#
# Cost function -7.518329796842869
# Epoch = 37
#  The first excited state Energy = -7.51833605 Ha, Sz= 0.00000000
# Number of gates = 41
#
# Circuit depth 22
#
# Cost function -7.518433274375503
# Epoch = 38
#  The first excited state Energy = -7.51843987 Ha, Sz= 0.00000000
# Number of gates = 42
#
# Circuit depth 22
#
# Cost function -7.518519303592106
# Epoch = 39
#  The first excited state Energy = -7.51852628 Ha, Sz= 0.00000000
# Number of gates = 43
#
# Circuit depth 23
#
# Cost function -7.518590357627693
# Epoch = 40
#  The first excited state Energy = -7.51859774 Ha, Sz= 0.00000000
# Number of gates = 44
#
# Circuit depth 24
#
# Cost function -7.5186486935873065
# Epoch = 41
#  The first excited state Energy = -7.51865639 Ha, Sz= 0.00000000
# Number of gates = 45
#
# Circuit depth 24
#
# Cost function -7.518696323263931
# Epoch = 42
#  The first excited state Energy = -7.51870427 Ha, Sz= 0.00000000
# Number of gates = 46
#
# Circuit depth 24
#
# Cost function -7.5187349755917685
# Epoch = 43
#  The first excited state Energy = -7.51874313 Ha, Sz= 0.00000000
# Number of gates = 47
#
# Circuit depth 25
#
# Cost function -7.518766140133545
# Epoch = 44
#  The first excited state Energy = -7.51877447 Ha, Sz= 0.00000000
# Number of gates = 48
#
# Circuit depth 26
#
# Cost function -7.5187910991181175
# Epoch = 45
#  The first excited state Energy = -7.51879958 Ha, Sz= 0.00000000
# Number of gates = 49
#
# Circuit depth 27
#
# Cost function -7.518810970694932
# Epoch = 46
#  The first excited state Energy = -7.51881964 Ha, Sz= 0.00000000
# Number of gates = 50
#
# Circuit depth 27
#
# Cost function -7.518826710720423
# Epoch = 47
#  The first excited state Energy = -7.51883560 Ha, Sz= 0.00000000
# Number of gates = 51
#
# Circuit depth 27
#
# Cost function -7.518839171362552
# Epoch = 48
#  The first excited state Energy = -7.51884764 Ha, Sz= 0.00000000
# Number of gates = 52
#
# Circuit depth 28
#
# Cost function -7.518849100925555
# Epoch = 49
#  The first excited state Energy = -7.51885670 Ha, Sz= 0.00000000
# Number of gates = 53
#
# Circuit depth 29
#
# Cost function -7.518857007499132
# Epoch = 50
#  The first excited state Energy = -7.51886358 Ha, Sz= -0.00000000
# Number of gates = 54
#
# Circuit depth 30
#
# Cost function -7.518863286160386
# Epoch = 51
#  The first excited state Energy = -7.51886893 Ha, Sz= 0.00000000
# Number of gates = 55
#
# Circuit depth 31
#
# Cost function -7.518868293578924
# Epoch = 52
#  The first excited state Energy = -7.51887348 Ha, Sz= 0.00000000
# Number of gates = 56
#
# Circuit depth 31
#
# Cost function -7.518872324791223
# Epoch = 53
#  The first excited state Energy = -7.51887729 Ha, Sz= 0.00000000
# Number of gates = 57
#
# Circuit depth 31
#
# Cost function -7.518875586609443
# Epoch = 54
#  The first excited state Energy = -7.51888045 Ha, Sz= -0.00000000
# Number of gates = 58
#
# Circuit depth 31
#
# Cost function -7.518878249798956
# Epoch = 55
#  The first excited state Energy = -7.51888288 Ha, Sz= 0.00000000
# Number of gates = 59
#
# Circuit depth 32
#
# Cost function -7.5188804543093894
# Epoch = 56
#  The first excited state Energy = -7.51888481 Ha, Sz= 0.00000000
# Number of gates = 60
#
# Circuit depth 33
#
# Cost function -7.518882308060749
# Epoch = 57
#  The first excited state Energy = -7.51888643 Ha, Sz= 0.00000000
# Number of gates = 61
#
# Circuit depth 34
#
# Cost function -7.518883899172146
# Epoch = 58
#  The first excited state Energy = -7.51888793 Ha, Sz= -0.00000000
# Number of gates = 62
#
# Circuit depth 35
#
# Cost function -7.518885301004596
# Epoch = 59
#  The first excited state Energy = -7.51888928 Ha, Sz= -0.00000000
# Number of gates = 63
#
# Circuit depth 36
#
# Cost function -7.5188865657169535
# Epoch = 60
#  The first excited state Energy = -7.51889051 Ha, Sz= -0.00000000
# Number of gates = 64
#
# Circuit depth 37
#
# Cost function -7.518887732283663
# Epoch = 61
#  The first excited state Energy = -7.51889164 Ha, Sz= 0.00000000
# Number of gates = 65
#
# Circuit depth 38
#
# Cost function -7.518888830047459
# Epoch = 62
#  The first excited state Energy = -7.51889271 Ha, Sz= 0.00000000
# Number of gates = 66
#
# Circuit depth 39
#
# Cost function -7.5188898811122336
# Epoch = 63
#  The first excited state Energy = -7.51889372 Ha, Sz= 0.00000000
# Number of gates = 67
#
# Circuit depth 40
#
# Cost function -7.518890902110904
# Epoch = 64
#  The first excited state Energy = -7.51889471 Ha, Sz= 0.00000000
# Number of gates = 68
#
# Circuit depth 41
