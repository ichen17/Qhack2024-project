# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.34.0-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.11.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.2.1)
# Collecting rustworkx (from pennylane)
#   Downloading rustworkx-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.6.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.4.4)
# Collecting semantic-version>=2.7 (from pennylane)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autoray>=0.6.1 (from pennylane)
#   Downloading autoray-0.6.8-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.3.2)
# Collecting pennylane-lightning>=0.34 (from pennylane)
#   Downloading PennyLane_Lightning-0.34.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.9.0)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2024.2.2)
# Installing collected packages: semantic-version, rustworkx, autoray, pennylane-lightning, pennylane
# Successfully installed autoray-0.6.8 pennylane-0.34.0 pennylane-lightning-0.34.0 rustworkx-0.14.0 semantic-version-2.10.0

# %%
import pennylane as qml
import pennylane.numpy as np
import matplotlib.pyplot as plt

# %%
def hydrogen_hamiltonian(coordinates):
    """Calculates the qubit Hamiltonian of the hydrogen molecule.

    Args:
        coordinates (list(float)): Cartesian coordinates of each hydrogen molecule.
        charge (int): The electric charge given to the hydrogen molecule.

    Returns:
        (qml.Hamiltonian): A PennyLane Hamiltonian.
    """
    return qml.qchem.molecular_hamiltonian(["H", "Li"], coordinates, charge=0, basis="STO-3G",active_electrons=2)[0]


def hf(electrons, num_qubits):
    """Calculates the Hartree-Fock state of the hydrogen molecule.

    Args:
        electrons (int): The number of electrons in the hydrogen molecule.
        num_qubits (int): The number of qubits needed to represent the hydrogen molecule Hamiltonian.

    Returns:
        (numpy.tensor): The HF state.
    """
    # Put your solution here #
    return qml.qchem.hf_state(electrons=electrons, orbitals=num_qubits)

# %%
def num_electrons(charge):
    """The total number of electrons in the hydrogen molecule.

    Args:
        charge (int): The electric charge given to the hydrogen molecule.

    Returns:
        (int): The number of electrons.
    """
    return 2-charge

# %%
def depth(qnode):
    def _fn(*args, **kwargs):
        qnode.construct(args, kwargs)
        return qnode.qtape.get_depth()
    return _fn

# %% [markdown]
# Using exact diagonalization to get the ground state and first excited state.

# %%
L=1.5
coordinates = np.array([0.0, 0.0, -L/2, 0.0, 0.0, L/2]) #np.array([-L/2/np.sqrt(3), L/2, 0.0, L/np.sqrt(3), 0.0, 0.0,-L/2/np.sqrt(3), -L/2, 0.0])
charge=0
hamiltonian = hydrogen_hamiltonian(np.array(coordinates))
H_matrix=qml.matrix(hamiltonian)

# %%
vals, vecs = np.linalg.eigh(H_matrix)

inds=np.argsort(vals)
eng=vals[inds]
vec=vecs[:,inds]

print('The ground state energy:',eng[0])
# Out:
# The ground state energy: -7.626624465547493

# %%
def vec_check(vec,electron_num):
    for i,e in enumerate(vec):
        if np.abs(e) > 1e-8:
            e_occ=bin(i)[2:]
            lst=' '.join(e_occ).split(' ')
            cv=tuple(map(int, lst))
            e_num=sum(cv)
            if e_num!=electron_num:
                return False
    return True

# %%
sz=qml.qchem.spinz(len(hamiltonian.wires))
SZ=qml.matrix(sz)
Stop=[False,False,False]
elec_num=2
for i in range(1,len(eng)): # Finding first excited state with -1 Sz
    Sz=vec[:,i].dot(SZ.dot(np.transpose(np.conjugate(vec[:,i]))))
    #print(Sz)

    if np.abs(Sz) < 1e-5 and vec_check(vec[:,i],elec_num):
        print('The first excied state energy with sz=1:',eng[i])
        Stop[0]=True

    elif np.abs(Sz-1) < 1e-5 and vec_check(vec[:,i],elec_num):
        print('The first excied state energy with sz=0:',eng[i])
        Stop[1]=True

    elif np.abs(Sz+1) < 1e-5 and vec_check(vec[:,i],elec_num):
        print('The first excied state energy with sz=-1:',eng[i])
        Stop[2]=True

    if np.all(Stop):
        break
# Out:
# The first excied state energy with sz=0: -7.522914627103037
# The first excied state energy with sz=1: -7.522914627103034
# The first excied state energy with sz=-1: -7.52291462710303

# %%
def bit_to_vec(bitstring_dict,num_qubits):
    vec=np.zeros(2**num_qubits)
    amp=0
    for i in range(2**num_qubits):
        bitstr=bin(i)[2:]
        if len(bitstr) < num_qubits:
            bitstr=(num_qubits-len(bitstr))*'0'+bitstr

        if bitstr in bitstring_dict:
            vec[i]=bitstring_dict[bitstr]
            amp+=np.abs(bitstring_dict[bitstr])**2
    vec=vec/np.sqrt(amp)
    return vec

# %%
class VQD_ch():
    def __init__(self,state_lst,num_electrons,symbol,geometry,charge) -> None:
        self.num_electrons=num_electrons
        self.symbol=symbol
        self.geometry=geometry
        self.charge=charge

        self.hamiltonian=self.Ch_hamiltonian(symbol,geometry,num_electrons,charge)
        self.num_qubits = len(self.hamiltonian.wires)
        self.sz=qml.qchem.spinz(self.num_qubits)
        self.singles, self.doubles = qml.qchem.excitations(self.num_electrons, self.num_qubits)
        self.state_lst=[]
        for stat in state_lst:
            self.state_lst.append(bit_to_vec(stat,self.num_qubits))
            #bit_lst=' '.join(stat).split(' ')
            #self.state_lst.append(list(map(int, bit_lst)))
        #self.stat_bitstr=state_lst

        self.weight_dict={}
        self.th_state=0
        self.Eng_lst=[]

        self.dev = qml.device("default.qubit", wires=self.num_qubits)
        self.cost_h_fn = qml.QNode(self.circuit, self.dev)
        self.Sz_fn = qml.QNode(self.circuit_sz, self.dev)
        self.cost_fid_fn = qml.QNode(self.circuit_fid, self.dev)
        self.num_ly_lst=[]

    def Ch_hamiltonian(self,symbol,geometry,num_electrons,charge):
        return qml.qchem.molecular_hamiltonian(symbol, geometry, charge=charge,\
                                               basis="STO-3G",active_electrons=num_electrons)[0]

    def hf(self,electrons, num_qubits):
        return qml.qchem.hf_state(electrons=electrons, orbitals=num_qubits)

    def circuit(self,state,weights):
        #qml.BasisState(state, wires=range(self.num_qubits))
        qml.StatePrep(state, wires=range(self.num_qubits))
        d_l=len(self.doubles)
        s_l=len(self.singles)
        for j in range(self.num_layer):
            for i in range(len(self.singles)):
                qml.SingleExcitation(weights[i+j*(d_l+s_l)], wires=self.singles[i])
            for i in range(len(self.doubles)):
                qml.DoubleExcitation(weights[i+s_l+j*(d_l+s_l)], wires=self.doubles[i])
        return qml.expval(self.hamiltonian)


    def circuit_sz(self,state,weights):
        #qml.BasisState(state, wires=range(self.num_qubits))
        qml.StatePrep(state, wires=range(self.num_qubits))
        d_l=len(self.doubles)
        s_l=len(self.singles)
        for j in range(self.num_layer):
            for i in range(len(self.singles)):
                qml.SingleExcitation(weights[i+j*(d_l+s_l)], wires=self.singles[i])
            for i in range(len(self.doubles)):
                qml.DoubleExcitation(weights[i+s_l+j*(d_l+s_l)], wires=self.doubles[i])
        return qml.expval(self.sz)

    def circuit_fid(self,state,params,weights,ind):
        #qml.BasisState(state, wires=range(num_qubits))
        qml.StatePrep(state, wires=range(self.num_qubits))
        Re_w=weights.copy()[::-1]
        d_l=len(self.doubles)
        s_l=len(self.singles)
        for j in range(self.num_layer):
            for i in range(len(self.singles)):
                qml.SingleExcitation(params[i+j*(d_l+s_l)], wires=self.singles[i])
            for i in range(len(self.doubles)):
                qml.DoubleExcitation(params[i+s_l+j*(d_l+s_l)], wires=self.doubles[i])

        Re_single=self.singles.copy()[::-1]
        Re_double=self.doubles.copy()[::-1]
        for j in range(self.num_ly_lst[ind]):
            for i in range(len(self.doubles)):
                qml.DoubleExcitation(-Re_w[i+j*(d_l+s_l)], wires=Re_double[i])
            for i in range(len(self.singles)):
                qml.SingleExcitation(-Re_w[i+d_l+j*(d_l+s_l)], wires=Re_single[i])

        return qml.state() #qml.probs(wires=range(num_qubits))

    def cost_fn(self,params):

        cost=self.cost_h_fn(self.stat,params)
        for ind in range(self.th_state):
            #print('hi')
            #stat_ind=int(self.stat_bitstr[ind],base=2)
            coj_stat=np.conjugate(np.transpose(self.state_lst[ind]))
            final_stat=self.cost_fid_fn(self.stat,params,self.weight_dict[ind],ind)
            #fid=self.cost_fid_fn(self.stat,params,self.weight_dict[ind],ind)
            fid=np.abs(np.dot(coj_stat,final_stat))**2
            cost+=self.beta*fid#[stat_ind]
        return cost

    def run(self,beta=3.0,epochs=400,stepsize=0.5,num_layer=2,cov=1e-6,print_train=True):

        if self.th_state==len(self.state_lst):
            print('Run of states')
            return None
        self.beta=beta
        self.stat=self.state_lst[self.th_state]
        self.num_layer=num_layer
        opt = qml.AdamOptimizer(stepsize=stepsize)
        self.weights =np.zeros(num_layer*len(self.singles+self.doubles), requires_grad=True)

        i=0
        iter=[]
        cost_val=[]
        Lowest_cost=0

        cov=cov
        E_pev=0

        for _ in range(epochs):
            self.weights = opt.step(self.cost_fn, self.weights)
            iter.append(i)
            cost=self.cost_fn(self.weights)

            E0=self.cost_h_fn(self.stat,self.weights)

            cost_val.append(E0)

            i=i+1
            if print_train:
                print('iter:',i)
                print(' E0:',E0,' Sz:',self.Sz_fn(self.stat,self.weights))
                print(cost)
            if np.abs(E0-E_pev)<cov:
                break

            E_pev=E0
        self.Eng_lst=E0
        self.weight_dict[self.th_state]=self.weights
        self.th_state+=1
        self.num_ly_lst.append(num_layer)
        return self.cost_h_fn(self.stat,self.weights)

# %%
L=1.5

#a0=0.529177210903
#L=r/a0
symbol=["H", "Li"]
geometry=np.array([0.0, 0.0, -L/2, 0.0, 0.0, L/2])

charge=0
num_electrons=2

g_stat={'1100000000': 1}
e_stat_0={'1001000000': 1}
e_stat_01={'1001000000': 1}
stat_lst=[g_stat,e_stat_0,e_stat_01]
VQD=VQD_ch(stat_lst,num_electrons,symbol,geometry,charge)

E0=VQD.run(num_layer=1)
# Out:
# iter: 1
#  E0: -7.475187554557702  Sz: 0.0
# -7.475187554557702
# iter: 2
#  E0: -7.53914631149875  Sz: -2.7755575615628914e-17
# -7.53914631149875
# iter: 3
#  E0: -7.58517297151212  Sz: 2.7755575615628914e-17
# -7.58517297151212
# iter: 4
#  E0: -7.53149154544308  Sz: 5.551115123125783e-17
# -7.53149154544308
# iter: 5
#  E0: -7.530700124349723  Sz: 0.0
# -7.530700124349723
# iter: 6
#  E0: -7.507674207729905  Sz: 2.7755575615628914e-17
# -7.5076639750922025
# iter: 100
#  E0: -7.507685270809856  Sz: -2.7755575615628914e-17
# -7.507672098055592
# iter: 101
#  E0: -7.507684682513056  Sz: 2.7755575615628914e-17
# -7.5076794725302936

# %%
electrons = 2
num_qubits = len(hamiltonian.wires)

S2 = qml.qchem.spin2(electrons, num_qubits)
sz=qml.qchem.spinz(num_qubits)

singles, doubles = qml.qchem.excitations(electrons, num_qubits)
pool_operators=singles+doubles

num_qubits = len(hamiltonian.wires)
hf_state = hf(electrons, num_qubits)

dev = qml.device("default.qubit", wires=num_qubits)
print("The original vqe use ",len(doubles)*13 + len(singles)*2," cnot gates")
print("The original vqe use ",len(doubles)*34 + len(singles)*10," gates")

bitstr=''.join(map(str, hf_state))

g_trial_stat={bitstr: 1}
e_trial_stat_szp1={'1010000000': 1}
e_trial_stat_szm1={'0101000000': 1}
e_trial_stat_sz0={'1001000000': 1,'0110000000': 1}

def bit_to_vec(bitstring_dict,num_qubits):
    vec=np.zeros(2**num_qubits)
    amp=0
    for i in range(2**num_qubits):
        bitstr=bin(i)[2:]
        if len(bitstr) < num_qubits:
            bitstr=(num_qubits-len(bitstr))*'0'+bitstr

        if bitstr in bitstring_dict:
            vec[i]=bitstring_dict[bitstr]
            amp+=np.abs(bitstring_dict[bitstr])**2
    vec=vec/np.sqrt(amp)
    return vec

g_stat=bit_to_vec(g_trial_stat,num_qubits)
#e_stat_szp1=bit_to_vec(e_trial_stat_szp1,num_qubits)

def circuit(state,weights):
    qml.StatePrep(state, wires=range(num_qubits))
    for i in range(len(singles)):
        qml.SingleExcitation(weights[i+len(doubles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(weights[i], wires=doubles[i])

    return qml.expval(hamiltonian)

def circuit_sz(state,weights):
    qml.StatePrep(state, wires=range(num_qubits))
    for i in range(len(singles)):
        qml.SingleExcitation(weights[i+len(doubles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(weights[i], wires=doubles[i])

    return qml.expval(sz)


cost_h_fn = qml.QNode(circuit, dev)
Sz_fn = qml.QNode(circuit_sz, dev)

def cost_fn(params):
    return cost_h_fn(g_stat,params)

weights =np.zeros(len(doubles + singles), requires_grad=True)

opt = qml.AdamOptimizer(stepsize=0.5)

i=0
iter=[]
cost_val=[]
Lowest_E=0
best_weights=0

cov=1e-6
E0_pev=0


for _ in range(400):
    weights = opt.step(cost_fn, weights)
    iter.append(i)

    E0=cost_h_fn(g_stat,weights)

    if Lowest_E>E0:
        Lowest_E=E0
        best_weights=weights
    cost_val.append(E0)

    i=i+1
    print('Need iter:',i,' E0:',E0,' Sz:',Sz_fn(g_stat,weights))
    if np.abs(E0-E0_pev)<cov:
        break

    E0_pev=E0
# Out:
# The original vqe use  224  cnot gates
# The original vqe use  624  gates
# Need iter: 1  E0: -7.475187554557702  Sz: 0.0
# Need iter: 2  E0: -7.53914631149875  Sz: -2.7755575615628914e-17
# Need iter: 3  E0: -7.58517297151212  Sz: 2.7755575615628914e-17
# Need iter: 4  E0: -7.53149154544308  Sz: 5.551115123125783e-17
# Need iter: 49  E0: -7.625878736080998  Sz: -8.326672684688674e-17
# Need iter: 50  E0: -7.625539825233521  Sz: -2.7755575615628914e-17
# Need iter: 51  E0: -7.626074582592784  Sz: -2.7755575615628914e-17
# Need iter: 52  E0: -7.62644081863421  Sz: 0.0
# Need iter: 53  E0: -7.626138892982933  Sz: 0.0
# Need iter: 54  E0: -7.626063235048788  Sz: -5.551115123125783e-17
# Need iter: 55  E0: -7.6263755447069554  Sz: -2.7755575615628914e-17
# Need iter: 56  E0: -7.626366784887171  Sz: 5.551115123125783e-17
# Need iter: 57  E0: -7.626176313261646  Sz: 0.0
# Need iter: 58  E0: -7.626311356664857  Sz: 0.0
# Need iter: 59  E0: -7.626495464513163  Sz: 2.7755575615628914e-17
# Need iter: 60  E0: -7.626421078879272  Sz: 2.7755575615628914e-17
# Need iter: 61  E0: -7.626342757313358  Sz: -2.7755575615628914e-17
# Need iter: 62  E0: -7.626443927251329  Sz: -5.551115123125783e-17
# Need iter: 63  E0: -7.6265123374241925  Sz: -2.7755575615628914e-17
# Need iter: 64  E0: -7.626446638997207  Sz: -2.7755575615628914e-17
# Need iter: 65  E0: -7.626446035647152  Sz: 0.0

# %%
def circuit_h(state,params):
    Re_w=weights[::-1]
    qml.StatePrep(state, wires=range(num_qubits))

    for i in range(len(singles)):
        qml.SingleExcitation(params[i+len(doubles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(params[i], wires=doubles[i])

    return qml.expval(hamiltonian)

def circuit_fid(state,params,weights):
    Re_w=weights[::-1]
    qml.StatePrep(state, wires=range(num_qubits))

    for i in range(len(singles)):
        qml.SingleExcitation(params[i+len(doubles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(params[i], wires=doubles[i])

    for i in range(len(singles)):
        qml.SingleExcitation(params[i+2*len(doubles)+len(singles)], wires=singles[i])
    for i in range(len(doubles)):
        qml.DoubleExcitation(params[i+len(doubles)+len(singles)], wires=doubles[i])

    for i, double in enumerate(doubles[::-1]):
        qml.DoubleExcitation(-Re_w[i], wires=double)
    for i, single in enumerate(singles[::-1]):
        qml.SingleExcitation(-Re_w[i+len(doubles)], wires=single)
    qml.PauliX(wires=0)
    qml.PauliX(wires=1)
    return qml.probs(wires=range(len(hamiltonian.wires)))

cost_h_fn = qml.QNode(circuit_h, dev)
cost_fid_fn = qml.QNode(circuit_fid, dev)
Sz_fn = qml.QNode(circuit_sz, dev)

params =np.zeros(2*len(doubles + singles), requires_grad=True)

e_trial_stat_sz0={'1010000000': 1}
e_stat_sz0=bit_to_vec(e_trial_stat_sz0,num_qubits)

def cost_fn(params):
    return cost_h_fn(e_stat_sz0,params)+cost_fid_fn(e_stat_sz0,params,weights)[0]

opt = qml.AdamOptimizer(stepsize=0.5)


i=0
iter=[]
cost_val=[]
Lowest_E=0
best_weights=0

cov=1e-6
E0_pev=0


for _ in range(400):
    params = opt.step(cost_fn, params)
    iter.append(i)

    E0=cost_h_fn(e_stat_sz0,params)

    if Lowest_E>E0:
        Lowest_E=E0
        best_weights=params
    cost_val.append(E0)

    i=i+1
    print('Need iter:',i,' E0:',E0,' Sz:',Sz_fn(e_stat_sz0,params))
    print("Cost function",cost_fn(params))
    if np.abs(E0-E0_pev)<cov:
        break

    E0_pev=E0

# %%
electrons = 2
num_qubits = len(hamiltonian.wires)

singles, doubles = qml.qchem.excitations(electrons, num_qubits)
pool_operators=singles+doubles

num_qubits = len(hamiltonian.wires)
hf_state = hf(electrons, num_qubits)

def circuit_1(state,weights,excitations):
    qml.StatePrep(state, wires=range(num_qubits))
    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(weights[i], wires=excitation)
        else:
            qml.SingleExcitation(weights[i], wires=excitation)
    return qml.expval(hamiltonian)

def circuit_sz(state,weights,excitations):
    qml.StatePrep(state, wires=range(num_qubits))
    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(weights[i], wires=excitation)
        else:
            qml.SingleExcitation(weights[i], wires=excitation)
    return qml.expval(sz)

dev = qml.device("default.qubit", wires=num_qubits)#

cost_h_fn = qml.QNode(circuit_1, dev, expansion_strategy="device")
Sz_fn = qml.QNode(circuit_sz, dev)

def cost_fn(params, excitations):
    return cost_h_fn(g_stat,params, excitations)


epochs=50

energy=[]
operator_circuits=[]# doubles_select+singles_select

weights = [] #[0.0] * len(operator_circuits)
weights=np.array(weights)

opt = opt = qml.GradientDescentOptimizer(stepsize=0.25)

circuit_gradient = qml.grad(cost_fn, argnum=0)


E0 = cost_h_fn(g_stat,weights, operator_circuits)

print(f"Epoch = 0, G Energy = {E0:.8f} Ha")

print("Number of gates = {}\n".format(len(operator_circuits)))

configs=qml.specs(cost_h_fn)(g_stat,weights, excitations=operator_circuits)

#print(configs)
print("Circuit depth {}\n".format(configs['resources'].depth))

conv=1e-7
E0_pev=0
E1_pev=0
E2_pev=0
E3_pev=0
for n in range(epochs):

    Test_set=operator_circuits+pool_operators
    Test_params=list(weights)+[0.0]*len(pool_operators)
    Test_params=np.array(Test_params)

    test_grads = circuit_gradient(Test_params,Test_set)
    test_grads = test_grads[len(weights):]
    maxpos = np.argmax(np.abs(test_grads))

    max_op=pool_operators[maxpos]
    operator_circuits.append(max_op)
    weights=np.append(weights, 0.0)

    weights,_ = opt.step(cost_fn, weights, operator_circuits) # Step 11.
    E0 = cost_h_fn(g_stat,weights,operator_circuits)


    print(f"Epoch = {n+1}, G Energy = {E0:.8f} Ha, Sz = {Sz_fn(g_stat,weights,operator_circuits):.8f} Ha,")
    print("Number of gates = {}\n".format(len(operator_circuits)))
    configs=qml.specs(cost_h_fn)(g_stat,weights, excitations=operator_circuits)
    print("Circuit depth {}\n".format(configs['resources'].depth))

    if np.abs(E0-E0_pev)<cov:
        break

    E0_pev=E0
# Out:
# Epoch = 0, G Energy = -7.60898166 Ha
# Number of gates = 0
#
# Circuit depth 1
#
# Epoch = 1, G Energy = -7.61248262 Ha, Sz = 0.00000000 Ha,
# Number of gates = 1
#
# Circuit depth 2
#
# Epoch = 2, G Energy = -7.61715784 Ha, Sz = 0.00000000 Ha,
# Number of gates = 2
#
# Circuit depth 3
#
# Epoch = 3, G Energy = -7.62030985 Ha, Sz = 0.00000000 Ha,
# Number of gates = 3
#
# Circuit depth 4
#
# Epoch = 4, G Energy = -7.62145953 Ha, Sz = 0.00000000 Ha,
# Number of gates = 4
#
# Circuit depth 5
#
# Epoch = 5, G Energy = -7.62183402 Ha, Sz = 0.00000000 Ha,
# Number of gates = 5
#
# Circuit depth 6
#
# Epoch = 6, G Energy = -7.62221333 Ha, Sz = 0.00000000 Ha,
# Number of gates = 6
#
# Circuit depth 7
#
# Epoch = 7, G Energy = -7.62268682 Ha, Sz = 0.00000000 Ha,
# Number of gates = 7
#
# Circuit depth 8
#
# Epoch = 8, G Energy = -7.62325700 Ha, Sz = 0.00000000 Ha,
# Number of gates = 8
#
# Circuit depth 9
#
# Epoch = 9, G Energy = -7.62387571 Ha, Sz = 0.00000000 Ha,
# Number of gates = 9
#
# Circuit depth 10
#
# Epoch = 10, G Energy = -7.62446129 Ha, Sz = 0.00000000 Ha,
# Number of gates = 10
#
# Circuit depth 11
#
# Epoch = 11, G Energy = -7.62496630 Ha, Sz = 0.00000000 Ha,
# Number of gates = 11
#
# Circuit depth 12
#
# Epoch = 12, G Energy = -7.62536293 Ha, Sz = 0.00000000 Ha,
# Number of gates = 12
#
# Circuit depth 13
#
# Epoch = 13, G Energy = -7.62565892 Ha, Sz = 0.00000000 Ha,
# Number of gates = 13
#
# Circuit depth 14
#
# Epoch = 14, G Energy = -7.62587067 Ha, Sz = 0.00000000 Ha,
# Number of gates = 14
#
# Circuit depth 15
#
# Epoch = 15, G Energy = -7.62601463 Ha, Sz = 0.00000000 Ha,
# Number of gates = 15
#
# Circuit depth 16
#
# Epoch = 16, G Energy = -7.62611445 Ha, Sz = 0.00000000 Ha,
# Number of gates = 16
#
# Circuit depth 17
#
# Epoch = 17, G Energy = -7.62619297 Ha, Sz = -0.00000000 Ha,
# Number of gates = 17
#
# Circuit depth 18
#
# Epoch = 18, G Energy = -7.62625497 Ha, Sz = 0.00000000 Ha,
# Number of gates = 18
#
# Circuit depth 19
#
# Epoch = 19, G Energy = -7.62629948 Ha, Sz = -0.00000000 Ha,
# Number of gates = 19
#
# Circuit depth 20
#
# Epoch = 20, G Energy = -7.62632745 Ha, Sz = 0.00000000 Ha,
# Number of gates = 20
#
# Circuit depth 21
#
# Epoch = 21, G Energy = -7.62634503 Ha, Sz = 0.00000000 Ha,
# Number of gates = 21
#
# Circuit depth 22
#
# Epoch = 22, G Energy = -7.62635941 Ha, Sz = -0.00000000 Ha,
# Number of gates = 22
#
# Circuit depth 23
#
# Epoch = 23, G Energy = -7.62637345 Ha, Sz = 0.00000000 Ha,
# Number of gates = 23
#
# Circuit depth 24
#
# Epoch = 24, G Energy = -7.62638843 Ha, Sz = 0.00000000 Ha,
# Number of gates = 24
#
# Circuit depth 24
#
# Epoch = 25, G Energy = -7.62640507 Ha, Sz = 0.00000000 Ha,
# Number of gates = 25
#
# Circuit depth 24
#
# Epoch = 26, G Energy = -7.62642332 Ha, Sz = 0.00000000 Ha,
# Number of gates = 26
#
# Circuit depth 24
#
# Epoch = 27, G Energy = -7.62644270 Ha, Sz = -0.00000000 Ha,
# Number of gates = 27
#
# Circuit depth 25
#
# Epoch = 28, G Energy = -7.62646249 Ha, Sz = 0.00000000 Ha,
# Number of gates = 28
#
# Circuit depth 26
#
# Epoch = 29, G Energy = -7.62648192 Ha, Sz = -0.00000000 Ha,
# Number of gates = 29
#
# Circuit depth 27
#
# Epoch = 30, G Energy = -7.62650040 Ha, Sz = 0.00000000 Ha,
# Number of gates = 30
#
# Circuit depth 27
#
# Epoch = 31, G Energy = -7.62651782 Ha, Sz = 0.00000000 Ha,
# Number of gates = 31
#
# Circuit depth 27
#
# Epoch = 32, G Energy = -7.62653393 Ha, Sz = -0.00000000 Ha,
# Number of gates = 32
#
# Circuit depth 27
#
# Epoch = 33, G Energy = -7.62654852 Ha, Sz = -0.00000000 Ha,
# Number of gates = 33
#
# Circuit depth 28
#
# Epoch = 34, G Energy = -7.62656143 Ha, Sz = 0.00000000 Ha,
# Number of gates = 34
#
# Circuit depth 29
#
# Epoch = 35, G Energy = -7.62657263 Ha, Sz = -0.00000000 Ha,
# Number of gates = 35
#
# Circuit depth 29
#
# Epoch = 36, G Energy = -7.62658222 Ha, Sz = 0.00000000 Ha,
# Number of gates = 36
#
# Circuit depth 29
#
# Epoch = 37, G Energy = -7.62659030 Ha, Sz = 0.00000000 Ha,
# Number of gates = 37
#
# Circuit depth 30
#
# Epoch = 38, G Energy = -7.62659702 Ha, Sz = 0.00000000 Ha,
# Number of gates = 38
#
# Circuit depth 30
#
# Epoch = 39, G Energy = -7.62660256 Ha, Sz = -0.00000000 Ha,
# Number of gates = 39
#
# Circuit depth 31
#
# Epoch = 40, G Energy = -7.62660706 Ha, Sz = 0.00000000 Ha,
# Number of gates = 40
#
# Circuit depth 32
#
# Epoch = 41, G Energy = -7.62661067 Ha, Sz = 0.00000000 Ha,
# Number of gates = 41
#
# Circuit depth 33
#
# Epoch = 42, G Energy = -7.62661354 Ha, Sz = 0.00000000 Ha,
# Number of gates = 42
#
# Circuit depth 34
#
# Epoch = 43, G Energy = -7.62661579 Ha, Sz = -0.00000000 Ha,
# Number of gates = 43
#
# Circuit depth 35
#
# Epoch = 44, G Energy = -7.62661758 Ha, Sz = -0.00000000 Ha,
# Number of gates = 44
#
# Circuit depth 35
#
# Epoch = 45, G Energy = -7.62661903 Ha, Sz = -0.00000000 Ha,
# Number of gates = 45
#
# Circuit depth 35
#
# Epoch = 46, G Energy = -7.62662021 Ha, Sz = -0.00000000 Ha,
# Number of gates = 46
#
# Circuit depth 35
#
# Epoch = 47, G Energy = -7.62662117 Ha, Sz = 0.00000000 Ha,
# Number of gates = 47
#
# Circuit depth 36

# %% [markdown]
# For $S_z=0$,

# %%
e_trial_stat_sz0={'1001000000': 1,'0110000000': 1}
e_stat_sz0=bit_to_vec(e_trial_stat_sz0,num_qubits)

def circuit_h(state,params,excitations):
    qml.StatePrep(state, wires=range(num_qubits))
    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(params[i], wires=excitation)
        else:
            qml.SingleExcitation(params[i], wires=excitation)

    return qml.expval(hamiltonian)


def circuit_fid(state,params,excitations):
    qml.StatePrep(state, wires=range(num_qubits))
    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(params[i], wires=excitation)
        else:
            qml.SingleExcitation(params[i], wires=excitation)

    Re_w=weights[::-1]
    for i, excitation in enumerate(operator_circuits[::-1]):
        if len(excitation) == 4:
            qml.DoubleExcitation(-Re_w[i], wires=excitation)
        else:
            qml.SingleExcitation(-Re_w[i], wires=excitation)
    qml.PauliX(wires=0)
    qml.PauliX(wires=1)
    return qml.probs(wires=range(num_qubits))

cost_h_fn = qml.QNode(circuit_h, dev, expansion_strategy="device")
fid_fn = qml.QNode(circuit_fid, dev)

def cost_fn(params, excitations):
    return cost_h_fn(e_stat_sz0,params, excitations)+5*fid_fn(e_stat_sz0,params, excitations)[0]

epochs=150

params = [0.0] * len(doubles)
params=np.array(params )

dev = qml.device("default.qubit", wires=num_qubits)

circuit_gradient = qml.grad(cost_fn, argnum=0)
grads_d = circuit_gradient(params, excitations=doubles)

params = [0.0] * len(singles)
params=np.array(params )

#dev = qml.device("default.qubit", wires=num_qubits)

#circuit_gradient = qml.grad(cost_fn, argnum=0)
grads_s = circuit_gradient(params, excitations=singles)

threshold=1e-5
doubles_select = [(doubles)[i] for i in range(len(doubles)) if abs(grads_d[i]) > threshold]
singles_select = [(singles)[i] for i in range(len(singles)) if abs(grads_s[i]) > threshold]

energy=[]
op_cir=doubles_select+singles_select
params = [0.0] * len(op_cir)
params=np.array(params )

opt = opt = qml.GradientDescentOptimizer(stepsize=0.03)

circuit_gradient = qml.grad(cost_fn, argnum=0)

E2 = cost_h_fn(e_stat_sz0,params, op_cir)


print(f"Epoch = 0, G Energy = {E2:.8f} Ha,")

print("Number of gates = {}\n".format(len(op_cir)))

configs=qml.specs(cost_h_fn)(g_stat,params, excitations=op_cir)

#print(configs)
print("Circuit depth {}\n".format(configs['resources'].depth))

conv=1e-7

E2_pev=0

for n in range(epochs):

    Test_set=op_cir+pool_operators
    Test_params=list(params)+[0.0]*len(pool_operators)
    Test_params=np.array(Test_params)

    test_grads = circuit_gradient(Test_params,Test_set)
    test_grads = test_grads[len(params):]
    maxpos = np.argmax(np.abs(test_grads))

    max_op=pool_operators[maxpos]
    op_cir.append(max_op)
    params=np.append(params, 0.0)

    params,_ = opt.step(cost_fn, params, op_cir) # Step 11.
    print('Cost function',cost_fn(params, op_cir))
    E2 = cost_h_fn(e_stat_sz0,params, op_cir)


    print(f"Epoch = {n+1}")
    print(f" The first excited state Energy = {E2:.8f} Ha, Sz= {Sz_fn(e_stat_sz0,params,op_cir):.8f}")
    print("Number of gates = {}\n".format(len(op_cir)))
    configs=qml.specs(cost_h_fn)(e_stat_sz0, params, excitations=op_cir)
    print("Circuit depth {}\n".format(configs['resources'].depth))

    if np.abs(E2-E2_pev)<cov:
        break
    E2_pev=E2
# Out:
# Epoch = 0, G Energy = -7.49074895 Ha,
# Number of gates = 4
#
# Circuit depth 3
#
# Cost function -7.491147378838875
# Epoch = 1
#  The first excited state Energy = -7.49114742 Ha, Sz= 0.00000000
# Number of gates = 5
#
# Circuit depth 4
#
# Cost function -7.491671058322511
# Epoch = 2
#  The first excited state Energy = -7.49167109 Ha, Sz= 0.00000000
# Number of gates = 6
#
# Circuit depth 4
#
# Cost function -7.492313507917783
# Epoch = 3
#  The first excited state Energy = -7.49231356 Ha, Sz= -0.00000000
# Number of gates = 7
#
# Circuit depth 5
#
# Cost function -7.49306564911569
# Epoch = 4
#  The first excited state Energy = -7.49306569 Ha, Sz= -0.00000000
# Number of gates = 8
#
# Circuit depth 5
#
# Cost function -7.493918227433652
# Epoch = 5
#  The first excited state Energy = -7.49391824 Ha, Sz= -0.00000000
# Number of gates = 9
#
# Circuit depth 6
#
# Cost function -7.494860678212293
# Epoch = 6
#  The first excited state Energy = -7.49486068 Ha, Sz= 0.00000000
# Number of gates = 10
#
# Circuit depth 6
#
# Cost function -7.495881592050727
# Epoch = 7
#  The first excited state Energy = -7.49588160 Ha, Sz= 0.00000000
# Number of gates = 11
#
# Circuit depth 7
#
# Cost function -7.496967765029356
# Epoch = 8
#  The first excited state Energy = -7.49696777 Ha, Sz= 0.00000000
# Number of gates = 12
#
# Circuit depth 7
#
# Cost function -7.498106601401803
# Epoch = 9
#  The first excited state Energy = -7.49810661 Ha, Sz= -0.00000000
# Number of gates = 13
#
# Circuit depth 8
#
# Cost function -7.499285158814238
# Epoch = 10
#  The first excited state Energy = -7.49928518 Ha, Sz= 0.00000000
# Number of gates = 14
#
# Circuit depth 8
#
# Cost function -7.500490570235264
# Epoch = 11
#  The first excited state Energy = -7.50049059 Ha, Sz= 0.00000000
# Number of gates = 15
#
# Circuit depth 9
#
# Cost function -7.501709305215298
# Epoch = 12
#  The first excited state Energy = -7.50170935 Ha, Sz= 0.00000000
# Number of gates = 16
#
# Circuit depth 9
#
# Cost function -7.502929264835174
# Epoch = 13
#  The first excited state Energy = -7.50292938 Ha, Sz= 0.00000000
# Number of gates = 17
#
# Circuit depth 10
#
# Cost function -7.504138968704499
# Epoch = 14
#  The first excited state Energy = -7.50413914 Ha, Sz= -0.00000000
# Number of gates = 18
#
# Circuit depth 10
#
# Cost function -7.505327816452169
# Epoch = 15
#  The first excited state Energy = -7.50532802 Ha, Sz= 0.00000000
# Number of gates = 19
#
# Circuit depth 11
#
# Cost function -7.506485496895679
# Epoch = 16
#  The first excited state Energy = -7.50648579 Ha, Sz= 0.00000000
# Number of gates = 20
#
# Circuit depth 11
#
# Cost function -7.507603626825449
# Epoch = 17
#  The first excited state Energy = -7.50760399 Ha, Sz= 0.00000000
# Number of gates = 21
#
# Circuit depth 12
#
# Cost function -7.508675015006465
# Epoch = 18
#  The first excited state Energy = -7.50867551 Ha, Sz= -0.00000000
# Number of gates = 22
#
# Circuit depth 12
#
# Cost function -7.509693681212121
# Epoch = 19
#  The first excited state Energy = -7.50969440 Ha, Sz= 0.00000000
# Number of gates = 23
#
# Circuit depth 13
#
# Cost function -7.5106544669874635
# Epoch = 20
#  The first excited state Energy = -7.51065538 Ha, Sz= -0.00000000
# Number of gates = 24
#
# Circuit depth 13
#
# Cost function -7.51155406192076
# Epoch = 21
#  The first excited state Energy = -7.51155513 Ha, Sz= 0.00000000
# Number of gates = 25
#
# Circuit depth 14
#
# Cost function -7.512390281188552
# Epoch = 22
#  The first excited state Energy = -7.51239160 Ha, Sz= -0.00000000
# Number of gates = 26
#
# Circuit depth 14
#
# Cost function -7.513162085145
# Epoch = 23
#  The first excited state Energy = -7.51316376 Ha, Sz= -0.00000000
# Number of gates = 27
#
# Circuit depth 15
#
# Cost function -7.5138692187787415
# Epoch = 24
#  The first excited state Energy = -7.51387120 Ha, Sz= 0.00000000
# Number of gates = 28
#
# Circuit depth 15
#
# Cost function -7.5145127005681145
# Epoch = 25
#  The first excited state Energy = -7.51451494 Ha, Sz= 0.00000000
# Number of gates = 29
#
# Circuit depth 16
#
# Cost function -7.515094266667531
# Epoch = 26
#  The first excited state Energy = -7.51509687 Ha, Sz= 0.00000000
# Number of gates = 30
#
# Circuit depth 16
#
# Cost function -7.515616365476306
# Epoch = 27
#  The first excited state Energy = -7.51561943 Ha, Sz= 0.00000000
# Number of gates = 31
#
# Circuit depth 17
#
# Cost function -7.516081859375512
# Epoch = 28
#  The first excited state Energy = -7.51608534 Ha, Sz= -0.00000000
# Number of gates = 32
#
# Circuit depth 17
#
# Cost function -7.516494200754746
# Epoch = 29
#  The first excited state Energy = -7.51649804 Ha, Sz= -0.00000000
# Number of gates = 33
#
# Circuit depth 18
#
# Cost function -7.516857063221736
# Epoch = 30
#  The first excited state Energy = -7.51686136 Ha, Sz= -0.00000000
# Number of gates = 34
#
# Circuit depth 18
#
# Cost function -7.517174341834666
# Epoch = 31
#  The first excited state Energy = -7.51717918 Ha, Sz= 0.00000000
# Number of gates = 35
#
# Circuit depth 19
#
# Cost function -7.5174499507705095
# Epoch = 32
#  The first excited state Energy = -7.51745527 Ha, Sz= -0.00000000
# Number of gates = 36
#
# Circuit depth 19
#
# Cost function -7.517687868502544
# Epoch = 33
#  The first excited state Energy = -7.51769362 Ha, Sz= 0.00000000
# Number of gates = 37
#
# Circuit depth 20
#
# Cost function -7.517891938559483
# Epoch = 34
#  The first excited state Energy = -7.51789821 Ha, Sz= 0.00000000
# Number of gates = 38
#
# Circuit depth 20
#
# Cost function -7.5180658922477654
# Epoch = 35
#  The first excited state Energy = -7.51807274 Ha, Sz= 0.00000000
# Number of gates = 39
#
# Circuit depth 21
#
# Cost function -7.518213243083592
# Epoch = 36
#  The first excited state Energy = -7.51822061 Ha, Sz= 0.00000000
# Number of gates = 40
#
# Circuit depth 21
#
# Cost function -7.5183373006612255
# Epoch = 37
#  The first excited state Energy = -7.51834514 Ha, Sz= 0.00000000
# Number of gates = 41
#
# Circuit depth 22
#
# Cost function -7.5184410923799865
# Epoch = 38
#  The first excited state Energy = -7.51844947 Ha, Sz= 0.00000000
# Number of gates = 42
#
# Circuit depth 22
#
# Cost function -7.518527403763958
# Epoch = 39
#  The first excited state Energy = -7.51853635 Ha, Sz= 0.00000000
# Number of gates = 43
#
# Circuit depth 23
#
# Cost function -7.518598742556897
# Epoch = 40
#  The first excited state Energy = -7.51860821 Ha, Sz= 0.00000000
# Number of gates = 44
#
# Circuit depth 23
#
# Cost function -7.518657354569731
# Epoch = 41
#  The first excited state Energy = -7.51866730 Ha, Sz= 0.00000000
# Number of gates = 45
#
# Circuit depth 24
#
# Cost function -7.51870521174846
# Epoch = 42
#  The first excited state Energy = -7.51871567 Ha, Sz= 0.00000000
# Number of gates = 46
#
# Circuit depth 24
#
# Cost function -7.518744055702432
# Epoch = 43
#  The first excited state Energy = -7.51875504 Ha, Sz= -0.00000000
# Number of gates = 47
#
# Circuit depth 25
#
# Cost function -7.518775397907146
# Epoch = 44
#  The first excited state Energy = -7.51878688 Ha, Sz= -0.00000000
# Number of gates = 48
#
# Circuit depth 25
#
# Cost function -7.518800538899051
# Epoch = 45
#  The first excited state Energy = -7.51881247 Ha, Sz= 0.00000000
# Number of gates = 49
#
# Circuit depth 26
#
# Cost function -7.518820580356913
# Epoch = 46
#  The first excited state Energy = -7.51883293 Ha, Sz= -0.00000000
# Number of gates = 50
#
# Circuit depth 27
#
# Cost function -7.518836463997465
# Epoch = 47
#  The first excited state Energy = -7.51884926 Ha, Sz= 0.00000000
# Number of gates = 51
#
# Circuit depth 27
#
# Cost function -7.518848983989626
# Epoch = 48
#  The first excited state Energy = -7.51886223 Ha, Sz= 0.00000000
# Number of gates = 52
#
# Circuit depth 27
#
# Cost function -7.518858794622558
# Epoch = 49
#  The first excited state Energy = -7.51887249 Ha, Sz= 0.00000000
# Number of gates = 53
#
# Circuit depth 28
#
# Cost function -7.518866493334601
# Epoch = 50
#  The first excited state Energy = -7.51888017 Ha, Sz= -0.00000000
# Number of gates = 54
#
# Circuit depth 28
#
# Cost function -7.518872623371123
# Epoch = 51
#  The first excited state Energy = -7.51888586 Ha, Sz= 0.00000000
# Number of gates = 55
#
# Circuit depth 29
#
# Cost function -7.5188775620924515
# Epoch = 52
#  The first excited state Energy = -7.51889005 Ha, Sz= 0.00000000
# Number of gates = 56
#
# Circuit depth 30
#
# Cost function -7.518881571133213
# Epoch = 53
#  The first excited state Energy = -7.51889313 Ha, Sz= 0.00000000
# Number of gates = 57
#
# Circuit depth 31
#
# Cost function -7.518884840831287
# Epoch = 54
#  The first excited state Energy = -7.51889541 Ha, Sz= 0.00000000
# Number of gates = 58
#
# Circuit depth 31
#
# Cost function -7.518887521364014
# Epoch = 55
#  The first excited state Energy = -7.51889717 Ha, Sz= 0.00000000
# Number of gates = 59
#
# Circuit depth 31
#
# Cost function -7.518889738092145
# Epoch = 56
#  The first excited state Energy = -7.51889858 Ha, Sz= -0.00000000
# Number of gates = 60
#
# Circuit depth 31
#
# Cost function -7.518891596919507
# Epoch = 57
#  The first excited state Energy = -7.51889977 Ha, Sz= 0.00000000
# Number of gates = 61
#
# Circuit depth 32
#
# Cost function -7.5188931849186975
# Epoch = 58
#  The first excited state Energy = -7.51890084 Ha, Sz= -0.00000000
# Number of gates = 62
#
# Circuit depth 33
#
# Cost function -7.5188945707622254
# Epoch = 59
#  The first excited state Energy = -7.51890183 Ha, Sz= 0.00000000
# Number of gates = 63
#
# Circuit depth 34
